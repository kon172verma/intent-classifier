# %% [markdown]
# # Phase 5 — DoRA+ Fine-Tuning — intent-classifier
#
# This notebook trains and evaluates DoRA+ adapters for **all 5 models × 4 configs** on
# Google Colab.
#
# **DoRA+** combines two independent improvements on top of vanilla LoRA:
# - **DoRA** (Weight-Decomposed Low-Rank Adaptation, Liu et al. 2024) — decomposes each
#   weight matrix into **magnitude** and **direction** components, then applies LoRA only
#   to the direction (`use_dora=True` in `LoraConfig`).
# - **LoRA+** (Hayou et al., 2024) — trains matrix B at a **higher learning rate** than
#   matrix A (`lr_B = loraplus_lr_ratio × lr_A`), which the original paper shows speeds up
#   convergence with no extra inference cost.
#
# The adapter structure is unchanged from LoRA, so inference/evaluation code is identical.
#
# **What runs here:**
# 1. Clone the repo from GitHub
# 2. Install dependencies
# 3. HF authentication (token stored in Colab Secrets)
# 4. GPU environment check
# 5. Configuration
# 6. Prepare data splits
# 7. Smoke test — 10 steps to validate the pipeline
# 8. Full training — all (model × config) combinations
# 9. Validation — load each adapter, evaluate on val split
# 10. Test evaluation (locked — run deliberately)
# 11. Inference sanity check
# 12. Download reports
#
# **Note:** Plot generation is done offline. Reports are JSON files — download them,
# then run `plot_doraplus_results.py` locally.

# %% [markdown]
# ## 1. Clone repository

# %%
import os

REPO_URL = "https://github.com/kon172verma/intent-classifier.git"
REPO_DIR = "/content/intent-classifier"

if not os.path.exists(REPO_DIR):
    os.system(f"git clone {REPO_URL} {REPO_DIR}")
else:
    os.system(f"git -C {REPO_DIR} pull")

print(f"Repo at: {REPO_DIR}")
# Out:
# Repo at: /content/intent-classifier

# %% [markdown]
# ## 2. Install dependencies

# %%
# %pip install -q \
    torch \
    "torchao>=0.16.0" \
    transformers \
    accelerate \
    "peft>=0.14.0" \
    trl \
    datasets \
    bitsandbytes \
    huggingface_hub \
    python-dotenv \
    sentencepiece \
    protobuf

print("Dependencies installed.")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 104.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 925.8/925.8 kB 51.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 559.1/559.1 kB 45.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.0/41.0 MB 58.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 MB 48.6 MB/s eta 0:00:00
# Dependencies installed.

# %% [markdown]
# ## 3. Hugging Face authentication
#
# Store your `HF_TOKEN` in **Colab Secrets** (key icon in the left sidebar).
# Required for:
# - Downloading `meta-llama/Llama-3.2-1B-Instruct` (gated model)
# - Uploading trained adapters to `kon172verma/intent-classifier`

# %%
import os

try:
    from google.colab import userdata  # type: ignore
    hf_token = userdata.get("HF_TOKEN")
    if hf_token:
        os.environ["HF_TOKEN"] = hf_token
        print("HF_TOKEN loaded from Colab Secrets.")
    else:
        print("WARNING: HF_TOKEN secret is empty.")
except Exception as e:
    print(f"Not running in Colab or secret missing: {e}")
# Out:
# HF_TOKEN loaded from Colab Secrets.

# %% [markdown]
# ## 4. GPU environment check

# %%
import subprocess
import platform
import torch

print(f"Python  : {platform.python_version()}")
print(f"PyTorch : {torch.__version__}")
print(f"CUDA    : {torch.version.cuda}")
if torch.cuda.is_available():
    props = torch.cuda.get_device_properties(0)
    print(f"GPU     : {props.name}  ({props.total_memory / 1e9:.1f} GB VRAM)")
else:
    print("GPU     : not available — training will be very slow on CPU")

# Verify DoRA + LoRA+ are supported in the installed PEFT version
import peft
print(f"PEFT    : {peft.__version__}  (DoRA requires >= 0.9.0, LoRA+ optimizer requires >= 0.9.0)")
# Out:
# Python  : 3.13.15
# PyTorch : 2.11.0+cu128
# CUDA    : 12.8
# GPU     : NVIDIA L4  (23.7 GB VRAM)
# WARNING:torchao:Failed to load /usr/local/lib/python3.13/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.13/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# WARNING:torchao:Failed to load /usr/local/lib/python3.13/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.13/dist-packages/torchao/_C_cutlass_90a.abi3.so
# PEFT    : 0.20.0  (DoRA requires >= 0.9.0, LoRA+ optimizer requires >= 0.9.0)

# %% [markdown]
# ## 5. Configuration
#
# Edit the variables below to control the experiment matrix.
#
# | Variable | Description |
# |---|---|
# | `MODELS_TO_RUN` | Which models to train (subset or all 5) |
# | `CONFIGS_TO_RUN` | Which configs (A / B / C / D) |
# | `DATASET_SIZE` | `"1k"` or `"10k"` |
# | `DEVICE` | `"auto"` (recommended) or `"cuda"` |
#
# **Config legend (same as LoRA — DoRA+ adds `use_dora=True` and an asymmetric LR ratio):**
# | Config | Description | loraplus_lr_ratio |
# |---|---|---|
# | A | Light — Q+V only, r=8 | 16 |
# | B | Standard — full attention, r=16 | 16 |
# | C | Wide — attn+MLP, r=16 | 16 |
# | D | Heavy — attn+MLP, r=32 | 8 |

# %%
import sys

REPO_DIR  = "/content/intent-classifier"
SRC_DIR   = f"{REPO_DIR}/finetune_DoRAplus/src"
DATA_DIR  = f"{REPO_DIR}/finetune_DoRAplus/data"

# ── Experiment matrix ──────────────────────────────────────────────────────
ALL_MODELS = [
    "smollm2-360m",
    "qwen2.5-0.5b",
    "qwen3-0.6b",
    "llama3.2-1b",
    "smollm2-1.7b",
]
ALL_CONFIGS = ["A", "B", "C", "D"]

MODELS_TO_RUN  = ALL_MODELS   # change to a subset for partial runs
CONFIGS_TO_RUN = ALL_CONFIGS  # change to e.g. ["A", "B"] for partial

DATASET_SIZE = "1k"           # "1k" or "10k"
DEVICE       = "auto"

SPLIT_DIR = f"{DATA_DIR}/{DATASET_SIZE}"

# Add repo root to path so finetune_lib is importable
if REPO_DIR not in sys.path:
    sys.path.insert(0, REPO_DIR)

print("Configuration:")
print(f"  Models   : {MODELS_TO_RUN}")
print(f"  Configs  : {CONFIGS_TO_RUN}")
print(f"  Dataset  : {DATASET_SIZE}")
print(f"  Device   : {DEVICE}")
# Out:
# Configuration:
#   Models   : ['smollm2-360m', 'qwen2.5-0.5b', 'qwen3-0.6b', 'llama3.2-1b', 'smollm2-1.7b']
#   Configs  : ['A', 'B', 'C', 'D']
#   Dataset  : 1k
#   Device   : auto

# %% [markdown]
# ## 6. Prepare data splits

# %%
import os
import subprocess
import sys

os.makedirs(SPLIT_DIR, exist_ok=True)

PREP_SCRIPT = f"{REPO_DIR}/finetune_DoRAplus/src/prepare_doraplus_data.py"
cmd = [
    sys.executable, "-u", PREP_SCRIPT,
    "--dataset-size", DATASET_SIZE,
    "--out-dir",      DATA_DIR,
]
print("Preparing data splits...")
proc = subprocess.Popen(
    cmd,
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True,
    bufsize=1,
    cwd=REPO_DIR,
)
_buf: list[str] = []
while True:
    ch = proc.stdout.read(1)
    if not ch:
        if _buf:
            line = "".join(_buf)
            if not line.startswith("Failed to load "):
                print(line, end="", flush=True)
        break
    _buf.append(ch)
    if ch in ("\r", "\n"):
        line = "".join(_buf)
        if not line.startswith("Failed to load "):
            print(line, end="", flush=True)
        _buf = []
proc.stdout.close()
proc.wait()
if proc.returncode != 0:
    raise RuntimeError("prepare_doraplus_data.py failed")
print("Data preparation complete.")
# Out:
# Preparing data splits...
#
#   Dataset size : 1k
#   Source dir   : /content/intent-classifier/dataset_full
#   Output dir   : /content/intent-classifier/finetune_DoRAplus/data/1k
#
#   Wrote   800 examples  →  /content/intent-classifier/finetune_DoRAplus/data/1k/train.jsonl
#   Wrote   100 examples  →  /content/intent-classifier/finetune_DoRAplus/data/1k/val.jsonl
#   Wrote   100 examples  →  /content/intent-classifier/finetune_DoRAplus/data/1k/test.jsonl
#   Wrote   100 examples  →  /content/intent-classifier/finetune_DoRAplus/data/1k/test_anchor.jsonl
#
#   Split summary (1k):
#     train        : 800
#     val          : 100
#     test         : 100
#     test_anchor  : 100  (sample_0001 only)
#
#   Done → /content/intent-classifier/finetune_DoRAplus/data/1k
# Data preparation complete.

# %% [markdown]
# ## 7. Smoke test
#
# Runs **10 training steps** on the first model + config A to validate the
# complete pipeline (data loading → tokenisation → PEFT DoRA+ → training → report save)
# without committing to a full run.
#
# **Safe to skip** if you have already validated the pipeline.

# %%
import subprocess
import sys
import time

SMOKE_MODEL  = MODELS_TO_RUN[0]
SMOKE_CONFIG = "A"

cmd = [
    sys.executable, "-u", f"{SRC_DIR}/doraplus_train.py",
    "--model",        SMOKE_MODEL,
    "--lora-config",  SMOKE_CONFIG,
    "--dataset-size", DATASET_SIZE,
    "--device",       DEVICE,
    "--smoke-test",
    "--no-push",
]
print("Running smoke test:", " ".join(cmd[2:]))
print()
t0 = time.time()
proc = subprocess.Popen(
    cmd,
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True,
    bufsize=1,
    cwd=REPO_DIR,
)
_buf: list[str] = []
while True:
    ch = proc.stdout.read(1)
    if not ch:
        if _buf:
            line = "".join(_buf)
            if not line.startswith("Failed to load "):
                print(line, end="", flush=True)
        break
    _buf.append(ch)
    if ch in ("\r", "\n"):
        line = "".join(_buf)
        if not line.startswith("Failed to load "):
            print(line, end="", flush=True)
        _buf = []
proc.stdout.close()
proc.wait()
elapsed = time.time() - t0
print(f"\nSmoke test {'PASSED' if proc.returncode == 0 else 'FAILED'} in {elapsed:.0f}s")
# Out:
# Running smoke test: /content/intent-classifier/finetune_DoRAplus/src/doraplus_train.py --model smollm2-360m --lora-config A --dataset-size 1k --device auto --smoke-test --no-push
#
#
# ============================================================
#   DoRA+ Training — smollm2-360m_A_1k
#   Model        : HuggingFaceTB/SmolLM2-360M-Instruct
#   LoRA config  : A — Light — attention Q/V only, rank 8
#   Dataset      : 1k
#   Device       : cuda
#   Adapter dest : /content/intent-classifier/finetune_DoRAplus/adapters/smollm2-360m_A_1k
#   HF repo      : kon172verma/intent-classifier-experiments/v2.0/smollm2-360m_DoRA+_A_1k_<timestamp>
#   Mode         : SMOKE TEST (10 steps only)
# ============================================================
#
#   Train : 800 examples
#   Val   : 100 examples
#
#   Loading tokenizer: HuggingFaceTB/SmolLM2-360M-Instruct
#   Loading model:     HuggingFaceTB/SmolLM2-360M-Instruct
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
#
# Loading weights:   0%|          | 0/290 [00:00<?, ?it/s]
# Loading weights:  54%|█████▍    | 158/290 [00:00<00:00, 1563.51it/s]
# Loading weights: 100%|██████████| 290/290 [00:00<00:00, 1612.11it/s]
#
#   Trainable params : 860,160  (0.237%)
#   Total params     : 362,681,280
#   Grad checkpoint  : disabled
#
#   Tokenizing datasets...
#
#   Effective batch  : 16
#   Steps / epoch    : 50
#   Total steps      : 10 (smoke)
#   Eval every       : 10 steps
#   LoRA+ optimizer  : ratio=16  lr_A=2.0e-04  lr_B=3.2e-03
#
# Truncating train dataset:   0%|          | 0/800 [00:00<?, ? examples/s]
# Truncating train dataset: 100%|██████████| 800/800 [00:00<00:00, 6054.39 examples/s]
# Truncating train dataset: 100%|██████████| 800/800 [00:00<00:00, 5967.46 examples/s]
#
# Dropping fully masked examples from train dataset:   0%|          | 0/800 [00:00<?, ? examples/s]
# Dropping fully masked examples from train dataset: 100%|██████████| 800/800 [00:00<00:00, 14415.95 examples/s]
#
# Truncating eval dataset:   0%|          | 0/100 [00:00<?, ? examples/s]
# Truncating eval dataset: 100%|██████████| 100/100 [00:00<00:00, 5437.76 examples/s]
#
# Dropping fully masked examples from eval dataset:   0%|          | 0/100 [00:00<?, ? examples/s]
# Dropping fully masked examples from eval dataset: 100%|██████████| 100/100 [00:00<00:00, 13552.31 examples/s]
#
#   Computing step-0 baseline (pre-fine-tuning)...
#
#   0%|          | 0/13 [00:00<?, ?it/s]
#  15%|█▌        | 2/13 [00:00<00:01, 10.50it/s]
#  31%|███       | 4/13 [00:00<00:01,  6.12it/s]
#  38%|███▊      | 5/13 [00:00<00:01,  5.16it/s]
#  46%|████▌     | 6/13 [00:01<00:01,  4.60it/s]
#  54%|█████▍    | 7/13 [00:01<00:01,  4.28it/s]
#  62%|██████▏   | 8/13 [00:01<00:01,  4.66it/s]
#  69%|██████▉   | 9/13 [00:01<00:00,  4.43it/s]
#  77%|███████▋  | 10/13 [00:02<00:00,  4.49it/s]
#  85%|████████▍ | 11/13 [00:02<00:00,  4.85it/s]
#  92%|█████████▏| 12/13 [00:02<00:00,  5.15it/s]
# 100%|██████████| 13/13 [00:02<00:00,  5.22it/s]
#   [Accuracy] step=0  train=0.0800  val=0.1400
#
# 100%|██████████| 13/13 [00:39<00:00,  3.02s/it]
#   Step 0 — train_loss=2.2897  val_loss=1.9399341344833374  train_acc=0.08  val_acc=0.14
#
#   Starting training (smoke-test: 10 steps)...
#
#
#   0%|          | 0/10 [00:00<?, ?it/s]
#  10%|█         | 1/10 [00:01<00:16,  1.84s/it]
#  20%|██        | 2/10 [00:03<00:12,  1.53s/it]
#  30%|███       | 3/10 [00:04<00:10,  1.47s/it]
#  40%|████      | 4/10 [00:05<00:08,  1.46s/it]
#  50%|█████     | 5/10 [00:07<00:06,  1.34s/it]
#  60%|██████    | 6/10 [00:08<00:05,  1.33s/it]
#  70%|███████   | 7/10 [00:09<00:03,  1.26s/it]
#  80%|████████  | 8/10 [00:10<00:02,  1.29s/it]
#  90%|█████████ | 9/10 [00:12<00:01,  1.31s/it]
# 100%|██████████| 10/10 [00:13<00:00,  1.28s/it]
#
# {'loss': '1.174', 'grad_norm': '2.676', 'learning_rate': '0.0002', 'entropy': '1.058', 'num_tokens': '6.793e+04', 'mean_token_accuracy': '0.7042', 'epoch': '0.2'}
#
# 100%|██████████| 10/10 [00:13<00:00,  1.28s/it]
#
#   0%|          | 0/13 [00:00<?, ?it/s]
#
#  15%|█▌        | 2/13 [00:00<00:01, 10.10it/s]
#
#  31%|███       | 4/13 [00:00<00:01,  5.92it/s]
#
#  38%|███▊      | 5/13 [00:00<00:01,  5.03it/s]
#
#  46%|████▌     | 6/13 [00:01<00:01,  4.52it/s]
#
#  54%|█████▍    | 7/13 [00:01<00:01,  4.19it/s]
#
#  62%|██████▏   | 8/13 [00:01<00:01,  4.56it/s]
#
#  69%|██████▉   | 9/13 [00:01<00:00,  4.34it/s]
#
#  77%|███████▋  | 10/13 [00:02<00:00,  4.44it/s]
#
#  85%|████████▍ | 11/13 [00:02<00:00,  4.77it/s]
#
#  92%|█████████▏| 12/13 [00:02<00:00,  5.06it/s]
#
# 100%|██████████| 13/13 [00:02<00:00,  5.93it/s]
#
#
#
# {'eval_loss': '1.031', 'eval_model_preparation_time': '0.0102', 'eval_runtime': '2.696', 'eval_samples_per_second': '37.09', 'eval_steps_per_second': '4.822', 'eval_entropy': '0.6142', 'eval_num_tokens': '6.793e+04', 'eval_mean_token_accuracy': '0.7276', 'epoch': '0.2'}
#
# 100%|██████████| 10/10 [00:16<00:00,  1.28s/it]
#
# 100%|██████████| 13/13 [00:02<00:00,  5.93it/s]
#   [Accuracy] step=10  train=0.2200  val=0.1800
#
#
#
#
# {'train_runtime': '39.59', 'train_samples_per_second': '4.042', 'train_steps_per_second': '0.253', 'train_loss': '1.174', 'epoch': '0.2'}
#
# 100%|██████████| 10/10 [00:39<00:00,  1.28s/it]
# 100%|██████████| 10/10 [00:39<00:00,  3.96s/it]
#
#   Training complete in 39.9s  |  Peak VRAM: 11197 MB
#
# ============================================================
#   TRAINING COMPLETE — smollm2-360m_A_1k
#   Final train loss : 1.1741
#   Final val loss   : 1.0311
#   Final val acc    : 0.1800
#   Final train acc  : 0.2200
#   Training time    : 39.9s
#   Peak VRAM        : 11197 MB
#   Training report  : /content/intent-classifier/finetune_DoRAplus/reports_training/smollm2-360m_A_1k_20260826_033710.json
# ============================================================
#
#
# Smoke test PASSED in 106s

# %% [markdown]
# ## 8. Train
#
# Runs all (model × config) combinations via `run_doraplus_experiments.py`.
#
# After each run the adapter is:
# 1. Saved locally → `finetune_DoRAplus/adapters/{run_tag}/`
# 2. Pushed to HF  → `kon172verma/intent-classifier/DoRA+/{run_tag}/`
#
# Training reports (JSON with full `log_history`) are saved to
# `finetune_DoRAplus/reports_training/`.
#
# **Estimated runtimes on L4 GPU (1k dataset, DoRA+ ~10-20% slower than LoRA,
# similar to DoRA — the asymmetric LR adds negligible overhead):**
#
# | Model | Config A | Config B | Config C | Config D |
# |---|---|---|---|---|
# | smollm2-360m   | ~9 min  | ~11 min | ~14 min | ~17 min |
# | qwen2.5-0.5b   | ~11 min | ~15 min | ~17 min | ~20 min |
# | qwen3-0.6b     | ~11 min | ~15 min | ~17 min | ~20 min |
# | llama3.2-1b    | ~22 min | ~28 min | ~32 min | ~38 min |
# | smollm2-1.7b   | ~28 min | ~34 min | ~39 min | ~47 min |

# %%
import subprocess
import sys
import time

cmd = [
    sys.executable, "-u", f"{SRC_DIR}/run_doraplus_experiments.py",
    "--models",       *MODELS_TO_RUN,
    "--configs",      *CONFIGS_TO_RUN,
    "--dataset-size", DATASET_SIZE,
    "--device",       DEVICE,
]
print("Running:", " ".join(cmd[2:]))
print()
t0 = time.time()
proc = subprocess.Popen(
    cmd,
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True,
    bufsize=1,
    cwd=REPO_DIR,
)
_buf: list[str] = []
while True:
    ch = proc.stdout.read(1)
    if not ch:
        if _buf:
            line = "".join(_buf)
            if not line.startswith("Failed to load "):
                print(line, end="", flush=True)
        break
    _buf.append(ch)
    if ch in ("\r", "\n"):
        line = "".join(_buf)
        if not line.startswith("Failed to load "):
            print(line, end="", flush=True)
        _buf = []
proc.stdout.close()
proc.wait()
elapsed = time.time() - t0
print(f"\nTraining {'complete' if proc.returncode == 0 else 'FAILED'} in {elapsed/60:.1f} min")
# Out:
# Streaming output truncated to the last 5000 lines.
#  23%|██▎       | 3/13 [00:00<00:02,  3.74it/s]
#
#  31%|███       | 4/13 [00:01<00:03,  2.77it/s]
#
#  38%|███▊      | 5/13 [00:01<00:03,  2.35it/s]
#
#  46%|████▌     | 6/13 [00:02<00:03,  2.15it/s]
#
#  54%|█████▍    | 7/13 [00:02<00:02,  2.00it/s]
#
#  62%|██████▏   | 8/13 [00:03<00:02,  2.24it/s]
#
#  69%|██████▉   | 9/13 [00:03<00:01,  2.15it/s]
#
#  77%|███████▋  | 10/13 [00:04<00:01,  2.20it/s]
#
#  85%|████████▍ | 11/13 [00:04<00:00,  2.38it/s]
#
#  92%|█████████▏| 12/13 [00:04<00:00,  2.52it/s]
#
# 100%|██████████| 13/13 [00:05<00:00,  3.00it/s]
#
#
#
# {'eval_loss': '0.1149', 'eval_model_preparation_time': '0.0144', 'eval_runtime': '5.385', 'eval_samples_per_second': '18.57', 'eval_steps_per_second': '2.414', 'eval_entropy': '0.03203', 'eval_num_tokens': '1.219e+06', 'eval_mean_token_accuracy': '0.9872', 'epoch': '4'}
#
# 100%|██████████| 200/200 [11:20<00:00,  2.89s/it]
#
# 100%|██████████| 13/13 [00:05<00:00,  3.00it/s]
#   [Accuracy] step=200  train=0.9800  val=0.9600
#
#
#
#
# {'train_runtime': '713', 'train_samples_per_second': '4.488', 'train_steps_per_second': '0.28', 'train_loss': '0.07549', 'epoch': '4'}
#
# 100%|██████████| 200/200 [11:53<00:00,  2.89s/it]
# 100%|██████████| 200/200 [11:53<00:00,  3.57s/it]
#
#   Training complete in 713.4s  |  Peak VRAM: 18980 MB
#
#   Saving adapter locally → /content/intent-classifier/finetune_DoRAplus/adapters/qwen3-0.6b_B_1k
#   Pushing adapter to HF → kon172verma/intent-classifier-experiments/v2.0/qwen3-0.6b_DoRA+_B_1k_20260826-050540
#   Adapter pushed successfully.
#   Report pushed  : kon172verma/intent-classifier-experiments/reports/v2.0/doraplus/reports_training/qwen3-0.6b_B_1k_20260826_050547.json
#
# ============================================================
#   TRAINING COMPLETE — qwen3-0.6b_B_1k
#   Final train loss : 0.0755
#   Final val loss   : 0.1149
#   Final val acc    : 0.9600
#   Final train acc  : 0.9800
#   Training time    : 713.4s
#   Peak VRAM        : 18980 MB
#   Training report  : /content/intent-classifier/finetune_DoRAplus/reports_training/qwen3-0.6b_B_1k_20260826_050547.json
#   Local adapter    : /content/intent-classifier/finetune_DoRAplus/adapters/qwen3-0.6b_B_1k
#   HF adapter       : kon172verma/intent-classifier-experiments/v2.0/qwen3-0.6b_DoRA+_B_1k_20260826-050540
# ============================================================
#
#
# ────────────────────────────────────────────────────────────
#   VAL    [10/20] qwen3-0.6b_B_1k
# ────────────────────────────────────────────────────────────
#
# ============================================================
#   DoRA+ Evaluation — qwen3-0.6b_B_1k
#   Split    : val  (100 examples)
#   Source   : local /content/intent-classifier/finetune_DoRAplus/adapters/qwen3-0.6b_B_1k
#   Device   : cuda
# ============================================================
#
#   Loading base model: Qwen/Qwen3-0.6B
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
#
# Loading weights:   0%|          | 0/311 [00:00<?, ?it/s]
# Loading weights:   1%|          | 2/311 [00:00<00:19, 16.08it/s]
# Loading weights:  41%|████      | 127/311 [00:00<00:00, 671.35it/s]
# Loading weights:  83%|████████▎ | 257/311 [00:00<00:00, 931.65it/s]
# Loading weights: 100%|██████████| 311/311 [00:00<00:00, 840.97it/s]
#   Loading adapter (local): /content/intent-classifier/finetune_DoRAplus/adapters/qwen3-0.6b_B_1k
#   [  20/100]  running_acc=1.000
#   [  40/100]  running_acc=0.975
#   [  60/100]  running_acc=0.967
#   [  80/100]  running_acc=0.975
#   [ 100/100]  running_acc=0.970
#
#   Accuracy   : 0.9700  (97/100)
#   Avg latency: 214.3 ms
#   Peak memory: 1304 MB
#   Report     : /content/intent-classifier/finetune_DoRAplus/reports_validation/qwen3-0.6b_B_1k_val_20260826_050625.json
#
# ────────────────────────────────────────────────────────────
#   TRAIN  [11/20] qwen3-0.6b_C_1k
# ────────────────────────────────────────────────────────────
#
# ============================================================
#   DoRA+ Training — qwen3-0.6b_C_1k
#   Model        : Qwen/Qwen3-0.6B
#   LoRA config  : C — Wide — full attention + MLP, rank 16
#   Dataset      : 1k
#   Device       : cuda
#   Adapter dest : /content/intent-classifier/finetune_DoRAplus/adapters/qwen3-0.6b_C_1k
#   HF repo      : kon172verma/intent-classifier-experiments/v2.0/qwen3-0.6b_DoRA+_C_1k_<timestamp>
# ============================================================
#
#   Train : 800 examples
#   Val   : 100 examples
#
#   Loading tokenizer: Qwen/Qwen3-0.6B
#   Loading model:     Qwen/Qwen3-0.6B
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
#
# Loading weights:   0%|          | 0/311 [00:00<?, ?it/s]
# Loading weights:   1%|          | 2/311 [00:00<00:19, 15.81it/s]
# Loading weights:  41%|████      | 127/311 [00:00<00:00, 667.96it/s]
# Loading weights:  82%|████████▏ | 256/311 [00:00<00:00, 926.83it/s]
# Loading weights: 100%|██████████| 311/311 [00:00<00:00, 837.85it/s]
#
#   Trainable params : 10,436,608  (1.721%)
#   Total params     : 606,486,528
#   Grad checkpoint  : disabled
#
#   Tokenizing datasets...
#
#   Effective batch  : 16
#   Steps / epoch    : 50
#   Total steps      : 200
#   Eval every       : 50 steps
#   LoRA+ optimizer  : ratio=16  lr_A=1.0e-04  lr_B=1.6e-03
#
# Truncating train dataset:   0%|          | 0/800 [00:00<?, ? examples/s]
# Truncating train dataset: 100%|██████████| 800/800 [00:00<00:00, 6672.44 examples/s]
# Truncating train dataset: 100%|██████████| 800/800 [00:00<00:00, 6572.30 examples/s]
#
# Dropping fully masked examples from train dataset:   0%|          | 0/800 [00:00<?, ? examples/s]
# Dropping fully masked examples from train dataset: 100%|██████████| 800/800 [00:00<00:00, 15307.33 examples/s]
#
# Truncating eval dataset:   0%|          | 0/100 [00:00<?, ? examples/s]
# Truncating eval dataset: 100%|██████████| 100/100 [00:00<00:00, 5899.08 examples/s]
#
# Dropping fully masked examples from eval dataset:   0%|          | 0/100 [00:00<?, ? examples/s]
# Dropping fully masked examples from eval dataset: 100%|██████████| 100/100 [00:00<00:00, 11128.43 examples/s]
#
#   Computing step-0 baseline (pre-fine-tuning)...
#
#   0%|          | 0/13 [00:00<?, ?it/s]
#  15%|█▌        | 2/13 [00:00<00:03,  3.08it/s]
#  23%|██▎       | 3/13 [00:01<00:04,  2.35it/s]
#  31%|███       | 4/13 [00:02<00:05,  1.74it/s]
#  38%|███▊      | 5/13 [00:02<00:05,  1.49it/s]
#  46%|████▌     | 6/13 [00:03<00:05,  1.36it/s]
#  54%|█████▍    | 7/13 [00:04<00:04,  1.28it/s]
#  62%|██████▏   | 8/13 [00:05<00:03,  1.41it/s]
#  69%|██████▉   | 9/13 [00:05<00:02,  1.36it/s]
#  77%|███████▋  | 10/13 [00:06<00:02,  1.38it/s]
#  85%|████████▍ | 11/13 [00:07<00:01,  1.48it/s]
#  92%|█████████▏| 12/13 [00:07<00:00,  1.57it/s]
# 100%|██████████| 13/13 [00:08<00:00,  1.87it/s]
#   [Accuracy] step=0  train=0.3000  val=0.2700
#
# 100%|██████████| 13/13 [00:54<00:00,  4.18s/it]
#   Step 0 — train_loss=2.1566  val_loss=2.5464611053466797  train_acc=0.3  val_acc=0.27
#
#   Starting training...
#
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'bos_token_id': None, 'pad_token_id': 151643}.
#
#   0%|          | 0/200 [00:00<?, ?it/s]Traceback (most recent call last):
#   File "/content/intent-classifier/finetune_DoRAplus/src/doraplus_train.py", line 50, in <module>
#     main()
#     ~~~~^^
#   File "/content/intent-classifier/finetune_DoRAplus/src/doraplus_train.py", line 41, in main
#     run_train_wrapper(
#     ~~~~~~~~~~~~~~~~~^
#         __file__,
#         ^^^^^^^^^
#     ...<2 lines>...
#         loraplus_configs=LORAPLUS_CONFIGS,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/content/intent-classifier/finetune_lib/wrappers.py", line 75, in run_train_wrapper
#     train_main(**kwargs)
#     ~~~~~~~~~~^^^^^^^^^^
#   File "/content/intent-classifier/finetune_LoRA/src/lora_train.py", line 465, in train_main
#     train_result = trainer.train()
#   File "/usr/local/lib/python3.13/dist-packages/transformers/trainer.py", line 1449, in train
#     return inner_training_loop(
#         args=args,
#     ...<2 lines>...
#         ignore_keys_for_eval=ignore_keys_for_eval,
#     )
#   File "/usr/local/lib/python3.13/dist-packages/transformers/trainer.py", line 1531, in _inner_training_loop
#     self._run_epoch(
#     ~~~~~~~~~~~~~~~^
#         model=model,
#         ^^^^^^^^^^^^
#     ...<9 lines>...
#         steps_trained_in_current_epoch=steps_trained_in_current_epoch,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/usr/local/lib/python3.13/dist-packages/transformers/trainer.py", line 1759, in _run_epoch
#     tr_loss_step = self.training_step(model, inputs, num_items_in_batch)
#   File "/usr/local/lib/python3.13/dist-packages/trl/trainer/sft_trainer.py", line 1846, in training_step
#     return super().training_step(*args, **kwargs)
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.13/dist-packages/transformers/trainer.py", line 1931, in training_step
#     loss = self.compute_loss(model, inputs, num_items_in_batch=num_items_in_batch)
#   File "/usr/local/lib/python3.13/dist-packages/trl/trainer/sft_trainer.py", line 1744, in compute_loss
#     (loss, outputs) = super().compute_loss(
#                       ~~~~~~~~~~~~~~~~~~~~^
#         model, inputs, return_outputs=True, num_items_in_batch=num_items_in_batch
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/usr/local/lib/python3.13/dist-packages/transformers/trainer.py", line 2005, in compute_loss
#     outputs = model(**inputs)
#   File "/usr/local/lib/python3.13/dist-packages/torch/nn/modules/module.py", line 1779, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.13/dist-packages/torch/nn/modules/module.py", line 1790, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.13/dist-packages/accelerate/utils/operations.py", line 943, in forward
#     return model_forward(*args, **kwargs)
#   File "/usr/local/lib/python3.13/dist-packages/accelerate/utils/operations.py", line 931, in __call__
#     return convert_to_fp32(self.model_forward(*args, **kwargs))
#                            ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.13/dist-packages/torch/amp/autocast_mode.py", line 44, in decorate_autocast
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.13/dist-packages/peft/peft_model.py", line 2101, in forward
#     return self.base_model(
#            ~~~~~~~~~~~~~~~^
#         input_ids=input_ids,
#         ^^^^^^^^^^^^^^^^^^^^
#     ...<6 lines>...
#         **kwargs,
#         ^^^^^^^^^
#     )
#     ^
#   File "/usr/local/lib/python3.13/dist-packages/torch/nn/modules/module.py", line 1779, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.13/dist-packages/torch/nn/modules/module.py", line 1790, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.13/dist-packages/peft/tuners/tuners_utils.py", line 333, in forward
#     return self.model.forward(*args, **kwargs)
#            ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.13/dist-packages/trl/trainer/sft_trainer.py", line 308, in _chunked_ce_forward
#     outputs: BaseModelOutputWithPast = backbone(
#                                        ~~~~~~~~^
#         input_ids=input_ids, attention_mask=attention_mask, use_cache=False, **decoder_kwargs, **kwargs
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/usr/local/lib/python3.13/dist-packages/torch/nn/modules/module.py", line 1779, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.13/dist-packages/torch/nn/modules/module.py", line 1790, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.13/dist-packages/transformers/utils/generic.py", line 1068, in wrapper
#     output = func(self, *args, **kwargs)
#   File "/usr/local/lib/python3.13/dist-packages/transformers/utils/output_capturing.py", line 262, in wrapper
#     outputs = func(self, *args, **kwargs)
#   File "/usr/local/lib/python3.13/dist-packages/transformers/models/qwen3/modeling_qwen3.py", line 413, in forward
#     hidden_states = decoder_layer(
#         hidden_states,
#     ...<5 lines>...
#         **kwargs,
#     )
#   File "/usr/local/lib/python3.13/dist-packages/transformers/modeling_layers.py", line 114, in __call__
#     return super().__call__(*args, **kwargs)
#            ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.13/dist-packages/torch/nn/modules/module.py", line 1779, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.13/dist-packages/torch/nn/modules/module.py", line 1790, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.13/dist-packages/transformers/models/qwen3/modeling_qwen3.py", line 321, in forward
#     hidden_states = self.mlp(hidden_states)
#   File "/usr/local/lib/python3.13/dist-packages/torch/nn/modules/module.py", line 1779, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.13/dist-packages/torch/nn/modules/module.py", line 1790, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.13/dist-packages/transformers/models/qwen3/modeling_qwen3.py", line 82, in forward
#     down_proj = self.down_proj(self.act_fn(self.gate_proj(x)) * self.up_proj(x))
#                                            ~~~~~~~~~~~~~~^^^
#   File "/usr/local/lib/python3.13/dist-packages/torch/nn/modules/module.py", line 1779, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.13/dist-packages/torch/nn/modules/module.py", line 1790, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.13/dist-packages/peft/tuners/lora/layer.py", line 1060, in forward
#     result = self.lora_variant[active_adapter].forward(
#         self,
#     ...<4 lines>...
#         **kwargs,
#     )
#   File "/usr/local/lib/python3.13/dist-packages/peft/tuners/lora/variants.py", line 237, in forward
#     result = result + module.lora_magnitude_vector[active_adapter](
#                       ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         x,
#         ^^
#     ...<5 lines>...
#         adapter_name=active_adapter,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/usr/local/lib/python3.13/dist-packages/torch/nn/modules/module.py", line 1779, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.13/dist-packages/torch/nn/modules/module.py", line 1790, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.13/dist-packages/peft/tuners/lora/dora.py", line 165, in forward
#     result_dora = (mag_norm_scale - 1) * base_result + mag_norm_scale * lora_result * scaling
#                                                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~
# torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 74.00 MiB. GPU 0 has a total capacity of 22.03 GiB of which 45.12 MiB is free. Including non-PyTorch memory, this process has 21.98 GiB memory in use. Of the allocated memory 21.26 GiB is allocated by PyTorch, and 501.44 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://docs.pytorch.org/docs/stable/notes/cuda.html#optimizing-memory-usage-with-pytorch-cuda-alloc-conf)
#
#   0%|          | 0/200 [00:01<?, ?it/s]
#
#   [ERROR] Exited with code 1
#
# ────────────────────────────────────────────────────────────
#   VAL    [11/20] qwen3-0.6b_C_1k
# ────────────────────────────────────────────────────────────
#
# ============================================================
#   DoRA+ Evaluation — qwen3-0.6b_C_1k
#   Split    : val  (100 examples)
#   Source   : local /content/intent-classifier/finetune_DoRAplus/adapters/qwen3-0.6b_C_1k
#   Device   : cuda
# ============================================================
#
#   Loading base model: Qwen/Qwen3-0.6B
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
#
# Loading weights:   0%|          | 0/311 [00:00<?, ?it/s]
# Loading weights:   0%|          | 1/311 [00:00<00:38,  8.06it/s]
# Loading weights:  41%|████      | 128/311 [00:00<00:00, 683.15it/s]
# Loading weights:  82%|████████▏ | 255/311 [00:00<00:00, 936.88it/s]
# Loading weights: 100%|██████████| 311/311 [00:00<00:00, 842.27it/s]
#   Loading adapter (local): /content/intent-classifier/finetune_DoRAplus/adapters/qwen3-0.6b_C_1k
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.13/dist-packages/peft/config.py", line 317, in _get_peft_type
#     config_file = hf_hub_download(
#         model_id,
#         CONFIG_NAME,
#         **hf_hub_download_kwargs,
#     )
#   File "/usr/local/lib/python3.13/dist-packages/huggingface_hub/utils/_validators.py", line 84, in _inner_fn
#     validate_repo_id(arg_value)
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^
#   File "/usr/local/lib/python3.13/dist-packages/huggingface_hub/utils/_validators.py", line 132, in validate_repo_id
#     raise HFValidationError(
#     ...<2 lines>...
#     )
# huggingface_hub.errors.HFValidationError: Repo id must be in the form 'repo_name' or 'namespace/repo_name': '/content/intent-classifier/finetune_DoRAplus/adapters/qwen3-0.6b_C_1k'. Use `repo_type` argument if needed.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/intent-classifier/finetune_DoRAplus/src/doraplus_validate.py", line 28, in <module>
#     run_validate_wrapper(
#     ~~~~~~~~~~~~~~~~~~~~^
#         __file__,
#         ^^^^^^^^^
#         technique="DoRA+",
#         ^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/content/intent-classifier/finetune_lib/wrappers.py", line 95, in run_validate_wrapper
#     lora_validate.validate_main(**kwargs)
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^
#   File "/content/intent-classifier/finetune_LoRA/src/lora_validate.py", line 314, in validate_main
#     model = PeftModel.from_pretrained(base_model, str(adapter_dir))
#   File "/usr/local/lib/python3.13/dist-packages/peft/peft_model.py", line 510, in from_pretrained
#     config = PEFT_TYPE_TO_CONFIG_MAPPING[PeftConfig._get_peft_type(model_id, **hf_kwargs)].from_pretrained(
#                                          ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.13/dist-packages/peft/config.py", line 323, in _get_peft_type
#     raise ValueError(f"Can't find '{CONFIG_NAME}' at '{model_id}'")
# ValueError: Can't find 'adapter_config.json' at '/content/intent-classifier/finetune_DoRAplus/adapters/qwen3-0.6b_C_1k'
#
#   [ERROR] Exited with code 1
#
# ────────────────────────────────────────────────────────────
#   TRAIN  [12/20] qwen3-0.6b_D_1k
# ────────────────────────────────────────────────────────────
#
# ============================================================
#   DoRA+ Training — qwen3-0.6b_D_1k
#   Model        : Qwen/Qwen3-0.6B
#   LoRA config  : D — Heavy — full attention + MLP, rank 32
#   Dataset      : 1k
#   Device       : cuda
#   Adapter dest : /content/intent-classifier/finetune_DoRAplus/adapters/qwen3-0.6b_D_1k
#   HF repo      : kon172verma/intent-classifier-experiments/v2.0/qwen3-0.6b_DoRA+_D_1k_<timestamp>
# ============================================================
#
#   Train : 800 examples
#   Val   : 100 examples
#
#   Loading tokenizer: Qwen/Qwen3-0.6B
#   Loading model:     Qwen/Qwen3-0.6B
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
#
# Loading weights:   0%|          | 0/311 [00:00<?, ?it/s]
# Loading weights:   1%|          | 2/311 [00:00<00:21, 14.58it/s]
# Loading weights:  42%|████▏     | 130/311 [00:00<00:00, 658.47it/s]
# Loading weights:  83%|████████▎ | 259/311 [00:00<00:00, 917.95it/s]
# Loading weights: 100%|██████████| 311/311 [00:00<00:00, 822.36it/s]
#
#   Trainable params : 20,529,152  (3.330%)
#   Total params     : 616,579,072
#   Grad checkpoint  : disabled
#
#   Tokenizing datasets...
#
#   Effective batch  : 16
#   Steps / epoch    : 50
#   Total steps      : 200
#   Eval every       : 50 steps
#   LoRA+ optimizer  : ratio=8  lr_A=5.0e-05  lr_B=4.0e-04
#
# Truncating train dataset:   0%|          | 0/800 [00:00<?, ? examples/s]
# Truncating train dataset: 100%|██████████| 800/800 [00:00<00:00, 6605.76 examples/s]
# Truncating train dataset: 100%|██████████| 800/800 [00:00<00:00, 6482.62 examples/s]
#
# Dropping fully masked examples from train dataset:   0%|          | 0/800 [00:00<?, ? examples/s]
# Dropping fully masked examples from train dataset: 100%|██████████| 800/800 [00:00<00:00, 14910.96 examples/s]
#
# Truncating eval dataset:   0%|          | 0/100 [00:00<?, ? examples/s]
# Truncating eval dataset: 100%|██████████| 100/100 [00:00<00:00, 5725.23 examples/s]
#
# Dropping fully masked examples from eval dataset:   0%|          | 0/100 [00:00<?, ? examples/s]
# Dropping fully masked examples from eval dataset: 100%|██████████| 100/100 [00:00<00:00, 11934.28 examples/s]
#
#   Computing step-0 baseline (pre-fine-tuning)...
#
#   0%|          | 0/13 [00:00<?, ?it/s]
#  15%|█▌        | 2/13 [00:00<00:03,  3.09it/s]
#  23%|██▎       | 3/13 [00:01<00:04,  2.35it/s]
#  31%|███       | 4/13 [00:02<00:05,  1.74it/s]
#  38%|███▊      | 5/13 [00:02<00:05,  1.49it/s]
#  46%|████▌     | 6/13 [00:03<00:05,  1.36it/s]
#  54%|█████▍    | 7/13 [00:04<00:04,  1.28it/s]
#  62%|██████▏   | 8/13 [00:05<00:03,  1.41it/s]
#  69%|██████▉   | 9/13 [00:05<00:02,  1.36it/s]
#  77%|███████▋  | 10/13 [00:06<00:02,  1.38it/s]
#  85%|████████▍ | 11/13 [00:07<00:01,  1.49it/s]
#  92%|█████████▏| 12/13 [00:07<00:00,  1.57it/s]
# 100%|██████████| 13/13 [00:08<00:00,  1.87it/s]
#   [Accuracy] step=0  train=0.3000  val=0.2700
#
# 100%|██████████| 13/13 [00:53<00:00,  4.09s/it]
#   Step 0 — train_loss=2.1566  val_loss=2.5464611053466797  train_acc=0.3  val_acc=0.27
#
#   Starting training...
#
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'bos_token_id': None, 'pad_token_id': 151643}.
#
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 1/200 [00:04<14:29,  4.37s/it]
#   1%|          | 2/200 [00:07<12:33,  3.80s/it]
#   2%|▏         | 3/200 [00:11<12:00,  3.66s/it]
#   2%|▏         | 4/200 [00:14<11:58,  3.67s/it]
#   2%|▎         | 5/200 [00:17<10:46,  3.32s/it]
#   3%|▎         | 6/200 [00:21<10:57,  3.39s/it]
#   4%|▎         | 7/200 [00:24<10:42,  3.33s/it]
#   4%|▍         | 8/200 [00:27<10:50,  3.39s/it]
#   4%|▍         | 9/200 [00:31<10:36,  3.33s/it]
#  92%|█████████▏| 12/13 [00:07<00:00,  1.53it/s]
#
# 100%|██████████| 13/13 [00:08<00:00,  1.82it/s]
#
#
#
# {'eval_loss': '0.03856', 'eval_model_preparation_time': '0.0215', 'eval_runtime': '8.776', 'eval_samples_per_second': '11.39', 'eval_steps_per_second': '1.481', 'eval_entropy': '0.01172', 'eval_num_tokens': '1.219e+06', 'eval_mean_token_accuracy': '0.9936', 'epoch': '4'}
#
# 100%|██████████| 200/200 [14:01<00:00,  3.34s/it]
#
# 100%|██████████| 13/13 [00:08<00:00,  1.82it/s]
#   [Accuracy] step=200  train=1.0000  val=0.9800
#
#
#
#
# {'train_runtime': '889.1', 'train_samples_per_second': '3.599', 'train_steps_per_second': '0.225', 'train_loss': '0.08628', 'epoch': '4'}
#
# 100%|██████████| 200/200 [14:49<00:00,  3.34s/it]
# 100%|██████████| 200/200 [14:49<00:00,  4.45s/it]
#
#   Training complete in 889.6s  |  Peak VRAM: 15516 MB
#
#   Saving adapter locally → /content/intent-classifier/finetune_DoRAplus/adapters/qwen3-0.6b_D_1k
#   Pushing adapter to HF → kon172verma/intent-classifier-experiments/v2.0/qwen3-0.6b_DoRA+_D_1k_20260826-052401
#   Adapter pushed successfully.
#   Report pushed  : kon172verma/intent-classifier-experiments/reports/v2.0/doraplus/reports_training/qwen3-0.6b_D_1k_20260826_052412.json
#
# ============================================================
#   TRAINING COMPLETE — qwen3-0.6b_D_1k
#   Final train loss : 0.0863
#   Final val loss   : 0.0386
#   Final val acc    : 0.9800
#   Final train acc  : 1.0000
#   Training time    : 889.6s
#   Peak VRAM        : 15516 MB
#   Training report  : /content/intent-classifier/finetune_DoRAplus/reports_training/qwen3-0.6b_D_1k_20260826_052412.json
#   Local adapter    : /content/intent-classifier/finetune_DoRAplus/adapters/qwen3-0.6b_D_1k
#   HF adapter       : kon172verma/intent-classifier-experiments/v2.0/qwen3-0.6b_DoRA+_D_1k_20260826-052401
# ============================================================
#
#
# ────────────────────────────────────────────────────────────
#   VAL    [12/20] qwen3-0.6b_D_1k
# ────────────────────────────────────────────────────────────
#
# ============================================================
#   DoRA+ Evaluation — qwen3-0.6b_D_1k
#   Split    : val  (100 examples)
#   Source   : local /content/intent-classifier/finetune_DoRAplus/adapters/qwen3-0.6b_D_1k
#   Device   : cuda
# ============================================================
#
#   Loading base model: Qwen/Qwen3-0.6B
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
#
# Loading weights:   0%|          | 0/311 [00:00<?, ?it/s]
# Loading weights:   0%|          | 1/311 [00:00<00:39,  7.81it/s]
# Loading weights:  42%|████▏     | 131/311 [00:00<00:00, 680.62it/s]
# Loading weights:  83%|████████▎ | 258/311 [00:00<00:00, 921.71it/s]
# Loading weights: 100%|██████████| 311/311 [00:00<00:00, 838.80it/s]
#   Loading adapter (local): /content/intent-classifier/finetune_DoRAplus/adapters/qwen3-0.6b_D_1k
#   [  20/100]  running_acc=1.000
#   [  40/100]  running_acc=0.975
#   [  60/100]  running_acc=0.983
#   [  80/100]  running_acc=0.988
#   [ 100/100]  running_acc=0.990
#
#   Accuracy   : 0.9900  (99/100)
#   Avg latency: 294.7 ms
#   Peak memory: 1394 MB
#   Report     : /content/intent-classifier/finetune_DoRAplus/reports_validation/qwen3-0.6b_D_1k_val_20260826_052459.json
#
# ────────────────────────────────────────────────────────────
#   TRAIN  [13/20] llama3.2-1b_A_1k
# ────────────────────────────────────────────────────────────
#
# ============================================================
#   DoRA+ Training — llama3.2-1b_A_1k
#   Model        : meta-llama/Llama-3.2-1B-Instruct
#   LoRA config  : A — Light — attention Q/V only, rank 8
#   Dataset      : 1k
#   Device       : cuda
#   Adapter dest : /content/intent-classifier/finetune_DoRAplus/adapters/llama3.2-1b_A_1k
#   HF repo      : kon172verma/intent-classifier-experiments/v2.0/llama3.2-1b_DoRA+_A_1k_<timestamp>
# ============================================================
#
#   Train : 800 examples
#   Val   : 100 examples
#
#   Loading tokenizer: meta-llama/Llama-3.2-1B-Instruct
#   Loading model:     meta-llama/Llama-3.2-1B-Instruct
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
#
# Loading weights:   0%|          | 0/146 [00:00<?, ?it/s]
# Loading weights:   1%|          | 1/146 [00:00<00:19,  7.42it/s]
# Loading weights:  21%|██        | 31/146 [00:00<00:00, 155.52it/s]
# Loading weights:  40%|████      | 59/146 [00:00<00:00, 206.19it/s]
# Loading weights:  62%|██████▏   | 91/146 [00:00<00:00, 248.05it/s]
# Loading weights:  82%|████████▏ | 120/146 [00:00<00:00, 260.10it/s]
# Loading weights: 100%|██████████| 146/146 [00:00<00:00, 232.32it/s]
#
#   Trainable params : 892,928  (0.072%)
#   Total params     : 1,236,707,328
#   Grad checkpoint  : enabled
#
#   Tokenizing datasets...
#
#   Effective batch  : 16
#   Steps / epoch    : 50
#   Total steps      : 200
#   Eval every       : 50 steps
#   LoRA+ optimizer  : ratio=16  lr_A=2.0e-04  lr_B=3.2e-03
#
# Truncating train dataset:   0%|          | 0/800 [00:00<?, ? examples/s]
# Truncating train dataset: 100%|██████████| 800/800 [00:00<00:00, 6360.31 examples/s]
# Truncating train dataset: 100%|██████████| 800/800 [00:00<00:00, 6258.42 examples/s]
#
# Dropping fully masked examples from train dataset:   0%|          | 0/800 [00:00<?, ? examples/s]
# Dropping fully masked examples from train dataset: 100%|██████████| 800/800 [00:00<00:00, 14722.02 examples/s]
#
# Truncating eval dataset:   0%|          | 0/100 [00:00<?, ? examples/s]
# Truncating eval dataset: 100%|██████████| 100/100 [00:00<00:00, 5466.03 examples/s]
#
# Dropping fully masked examples from eval dataset:   0%|          | 0/100 [00:00<?, ? examples/s]
# Dropping fully masked examples from eval dataset: 100%|██████████| 100/100 [00:00<00:00, 12256.88 examples/s]
#
#   Computing step-0 baseline (pre-fine-tuning)...
#
#   0%|          | 0/13 [00:00<?, ?it/s]
#  15%|█▌        | 2/13 [00:00<00:01,  5.57it/s]
#  23%|██▎       | 3/13 [00:00<00:02,  4.25it/s]
#  31%|███       | 4/13 [00:01<00:02,  3.15it/s]
#  38%|███▊      | 5/13 [00:01<00:02,  2.73it/s]
#  46%|████▌     | 6/13 [00:02<00:02,  2.49it/s]
#  54%|█████▍    | 7/13 [00:02<00:02,  2.35it/s]
#  62%|██████▏   | 8/13 [00:02<00:01,  2.58it/s]
#  69%|██████▉   | 9/13 [00:03<00:01,  2.49it/s]
#  77%|███████▋  | 10/13 [00:03<00:01,  2.51it/s]
#  85%|████████▍ | 11/13 [00:03<00:00,  2.69it/s]
#  92%|█████████▏| 12/13 [00:04<00:00,  2.84it/s]
# 100%|██████████| 13/13 [00:04<00:00,  3.26it/s][transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer TokenizersBackend. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
#
#   [Accuracy] step=0  train=0.1600  val=0.1100
#
# 100%|██████████| 13/13 [00:39<00:00,  3.02s/it]
#   Step 0 — train_loss=1.9367  val_loss=2.0686569213867188  train_acc=0.16  val_acc=0.11
#
#   Starting training...
#
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 128009, 'pad_token_id': 128009}.
#
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          |
#  94%|█████████▍| 188/200 [47:58<02:31, 12.65s/it]
#  94%|█████████▍| 189/200 [48:14<02:27, 13.44s/it]
#  95%|█████████▌| 190/200 [48:27<02:13, 13.33s/it]
#  96%|█████████▌| 191/200 [48:39<01:57, 13.11s/it]
#  96%|█████████▌| 192/200 [48:50<01:39, 12.48s/it]
#  96%|█████████▋| 193/200 [49:03<01:28, 12.60s/it]
#  97%|█████████▋| 194/200 [49:17<01:18, 13.06s/it]
#  98%|█████████▊| 195/200 [49:32<01:07, 13.43s/it]
#  98%|█████████▊| 196/200 [49:45<00:53, 13.47s/it]
#  98%|█████████▊| 197/200 [49:58<00:39, 13.20s/it]
#  99%|█████████▉| 198/200 [50:09<00:25, 12.61s/it]
# 100%|█████████▉| 199/200 [50:23<00:13, 13.15s/it]
# 100%|██████████| 200/200 [50:37<00:00, 13.26s/it]
#
# {'loss': '0.001074', 'grad_norm': '0.01499', 'learning_rate': '4.867e-05', 'entropy': '0.006413', 'num_tokens': '1.387e+06', 'mean_token_accuracy': '1', 'epoch': '4'}
#
# 100%|██████████| 200/200 [50:37<00:00, 13.26s/it]
#
#   0%|          | 0/13 [00:00<?, ?it/s]
#
#  15%|█▌        | 2/13 [00:01<00:09,  1.17it/s]
#
#  23%|██▎       | 3/13 [00:03<00:11,  1.15s/it]
#
#  31%|███       | 4/13 [00:05<00:13,  1.50s/it]
#
#  38%|███▊      | 5/13 [00:07<00:13,  1.71s/it]
#
#  46%|████▌     | 6/13 [00:09<00:12,  1.85s/it]
#
#  54%|█████▍    | 7/13 [00:11<00:11,  1.96s/it]
#
#  62%|██████▏   | 8/13 [00:13<00:09,  1.82s/it]
#
#  69%|██████▉   | 9/13 [00:15<00:07,  1.89s/it]
#
#  77%|███████▋  | 10/13 [00:17<00:05,  1.87s/it]
#
#  85%|████████▍ | 11/13 [00:18<00:03,  1.77s/it]
#
#  92%|█████████▏| 12/13 [00:20<00:01,  1.70s/it]
#
# 100%|██████████| 13/13 [00:21<00:00,  1.48s/it]
#
#
#
# {'eval_loss': '0.1013', 'eval_model_preparation_time': '0.0182', 'eval_runtime': '22.59', 'eval_samples_per_second': '4.426', 'eval_steps_per_second': '0.575', 'eval_entropy': '0.009106', 'eval_num_tokens': '1.387e+06', 'eval_mean_token_accuracy': '0.9904', 'epoch': '4'}
#
# 100%|██████████| 200/200 [51:00<00:00, 13.26s/it]
#
# 100%|██████████| 13/13 [00:21<00:00,  1.48s/it]
#   [Accuracy] step=200  train=1.0000  val=0.9700
#
#
#
#
# {'train_runtime': '3168', 'train_samples_per_second': '1.01', 'train_steps_per_second': '0.063', 'train_loss': '0.06535', 'epoch': '4'}
#
# 100%|██████████| 200/200 [52:48<00:00, 13.26s/it]
# 100%|██████████| 200/200 [52:48<00:00, 15.84s/it]
#
#   Training complete in 3168.9s  |  Peak VRAM: 5969 MB
#
#   Saving adapter locally → /content/intent-classifier/finetune_DoRAplus/adapters/smollm2-1.7b_D_1k
#   Pushing adapter to HF → kon172verma/intent-classifier-experiments/v2.0/smollm2-1.7b_DoRA+_D_1k_20260826-094624
#   Adapter pushed successfully.
#   Report pushed  : kon172verma/intent-classifier-experiments/reports/v2.0/doraplus/reports_training/smollm2-1.7b_D_1k_20260826_094637.json
#
# ============================================================
#   TRAINING COMPLETE — smollm2-1.7b_D_1k
#   Final train loss : 0.0654
#   Final val loss   : 0.1013
#   Final val acc    : 0.9700
#   Final train acc  : 1.0000
#   Training time    : 3168.9s
#   Peak VRAM        : 5969 MB
#   Training report  : /content/intent-classifier/finetune_DoRAplus/reports_training/smollm2-1.7b_D_1k_20260826_094637.json
#   Local adapter    : /content/intent-classifier/finetune_DoRAplus/adapters/smollm2-1.7b_D_1k
#   HF adapter       : kon172verma/intent-classifier-experiments/v2.0/smollm2-1.7b_DoRA+_D_1k_20260826-094624
# ============================================================
#
#
# ────────────────────────────────────────────────────────────
#   VAL    [20/20] smollm2-1.7b_D_1k
# ────────────────────────────────────────────────────────────
#
# ============================================================
#   DoRA+ Evaluation — smollm2-1.7b_D_1k
#   Split    : val  (100 examples)
#   Source   : local /content/intent-classifier/finetune_DoRAplus/adapters/smollm2-1.7b_D_1k
#   Device   : cuda
# ============================================================
#
#   Loading base model: HuggingFaceTB/SmolLM2-1.7B-Instruct
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
#
# Loading weights:   0%|          | 0/218 [00:00<?, ?it/s]
# Loading weights:  10%|▉         | 21/218 [00:00<00:01, 196.47it/s]
# Loading weights:  22%|██▏       | 48/218 [00:00<00:00, 236.23it/s]
# Loading weights:  34%|███▍      | 75/218 [00:00<00:00, 248.32it/s]
# Loading weights:  47%|████▋     | 102/218 [00:00<00:00, 252.21it/s]
# Loading weights:  59%|█████▉    | 129/218 [00:00<00:00, 254.92it/s]
# Loading weights:  72%|███████▏  | 156/218 [00:00<00:00, 257.83it/s]
# Loading weights:  84%|████████▍ | 183/218 [00:00<00:00, 259.26it/s]
# Loading weights:  96%|█████████▋| 210/218 [00:00<00:00, 260.73it/s]
# Loading weights: 100%|██████████| 218/218 [00:00<00:00, 255.46it/s]
#   Loading adapter (local): /content/intent-classifier/finetune_DoRAplus/adapters/smollm2-1.7b_D_1k
#   [  20/100]  running_acc=1.000
#   [  40/100]  running_acc=0.975
#   [  60/100]  running_acc=0.967
#   [  80/100]  running_acc=0.963
#   [ 100/100]  running_acc=0.960
#
#   Accuracy   : 0.9600  (96/100)
#   Avg latency: 714.7 ms
#   Peak memory: 3969 MB
#   Report     : /content/intent-classifier/finetune_DoRAplus/reports_validation/smollm2-1.7b_D_1k_val_20260826_094805.json
#
# ============================================================
#   EXPERIMENT RUNNER COMPLETE
#   Completed at: 2026-08-26 09:48:07
#
#   smollm2-360m_A_1k                    train=OK  val=OK
#   smollm2-360m_B_1k                    train=OK  val=OK
#   smollm2-360m_C_1k                    train=FAIL  val=FAIL
#   smollm2-360m_D_1k                    train=OK  val=OK
#   qwen2.5-0.5b_A_1k                    train=OK  val=OK
#   qwen2.5-0.5b_B_1k                    train=OK  val=OK
#   qwen2.5-0.5b_C_1k                    train=FAIL  val=FAIL
#   qwen2.5-0.5b_D_1k                    train=OK  val=OK
#   qwen3-0.6b_A_1k                      train=OK  val=OK
#   qwen3-0.6b_B_1k                      train=OK  val=OK
#   qwen3-0.6b_C_1k                      train=FAIL  val=FAIL
#   qwen3-0.6b_D_1k                      train=OK  val=OK
#   llama3.2-1b_A_1k                     train=OK  val=OK
#   llama3.2-1b_B_1k                     train=OK  val=OK
#   llama3.2-1b_C_1k                     train=OK  val=OK
#   llama3.2-1b_D_1k                     train=OK  val=OK
#   smollm2-1.7b_A_1k                    train=OK  val=OK
#   smollm2-1.7b_B_1k                    train=OK  val=OK
#   smollm2-1.7b_C_1k                    train=OK  val=OK
#   smollm2-1.7b_D_1k                    train=OK  val=OK
# ============================================================
#
#
# Training complete in 370.9 min

# %% [markdown]
# ## 9. Validation
#
# Evaluates each adapter on the validation split.
# Reports are saved to `finetune_DoRAplus/reports_validation/`.

# %%
import subprocess
import sys
import time

cmd = [
    sys.executable, "-u", f"{SRC_DIR}/run_doraplus_experiments.py",
    "--models",       *MODELS_TO_RUN,
    "--configs",      *CONFIGS_TO_RUN,
    "--dataset-size", DATASET_SIZE,
    "--device",       DEVICE,
    "--skip-training",  # adapters already uploaded; load from HF
]
print("Running validation:", " ".join(cmd[2:]))
print()
t0 = time.time()
proc = subprocess.Popen(
    cmd,
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True,
    bufsize=1,
    cwd=REPO_DIR,
)
_buf: list[str] = []
while True:
    ch = proc.stdout.read(1)
    if not ch:
        if _buf:
            line = "".join(_buf)
            if not line.startswith("Failed to load "):
                print(line, end="", flush=True)
        break
    _buf.append(ch)
    if ch in ("\r", "\n"):
        line = "".join(_buf)
        if not line.startswith("Failed to load "):
            print(line, end="", flush=True)
        _buf = []
proc.stdout.close()
proc.wait()
print(f"\nValidation {'complete' if proc.returncode == 0 else 'FAILED'} in {time.time()-t0:.0f}s")
# Out:
# Running validation: /content/intent-classifier/finetune_DoRAplus/src/run_doraplus_experiments.py --models smollm2-360m qwen2.5-0.5b qwen3-0.6b llama3.2-1b smollm2-1.7b --configs A B C D --dataset-size 1k --device auto --skip-training
#
#
# ============================================================
#   DoRA+ Experiment Runner
#   Models   : ['smollm2-360m', 'qwen2.5-0.5b', 'qwen3-0.6b', 'llama3.2-1b', 'smollm2-1.7b']
#   Configs  : ['A', 'B', 'C', 'D']
#   Dataset  : 1k
#   Device   : auto
#   Runs     : 20 training + 20 val eval
#   Training : SKIPPED
# ============================================================
#
# ────────────────────────────────────────────────────────────
#   VAL    [1/20] smollm2-360m_A_1k
# ────────────────────────────────────────────────────────────
#
# ============================================================
#   DoRA+ Evaluation — smollm2-360m_A_1k
#   Split    : val  (100 examples)
#   Source   : kon172verma/intent-classifier-experiments/v2.0/smollm2-360m_DoRA+_A_1k_20260826-034416
#   Device   : cuda
# ============================================================
#
#   Loading base model: HuggingFaceTB/SmolLM2-360M-Instruct
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
#
# Loading weights:   0%|          | 0/290 [00:00<?, ?it/s]
# Loading weights:  50%|█████     | 146/290 [00:00<00:00, 1458.75it/s]
# Loading weights: 100%|██████████| 290/290 [00:00<00:00, 1489.56it/s]
#   Loading adapter from HF: kon172verma/intent-classifier-experiments/v2.0/smollm2-360m_DoRA+_A_1k_20260826-034416
#   [  20/100]  running_acc=0.850
#   [  40/100]  running_acc=0.725
#   [  60/100]  running_acc=0.667
#   [  80/100]  running_acc=0.650
#   [ 100/100]  running_acc=0.620
#   Report pushed  : kon172verma/intent-classifier-experiments/reports/v2.0/doraplus/reports_validation/smollm2-360m_A_1k_val_20260826_094849.json
#
#   Accuracy   : 0.6200  (62/100)
#   Avg latency: 150.1 ms
#   Peak memory: 768 MB
#   Report     : /content/intent-classifier/finetune_DoRAplus/reports_validation/smollm2-360m_A_1k_val_20260826_094849.json
#
# ────────────────────────────────────────────────────────────
#   VAL    [2/20] smollm2-360m_B_1k
# ────────────────────────────────────────────────────────────
#
# ============================================================
#   DoRA+ Evaluation — smollm2-360m_B_1k
#   Split    : val  (100 examples)
#   Source   : kon172verma/intent-classifier-experiments/v2.0/smollm2-360m_DoRA+_B_1k_20260826-035402
#   Device   : cuda
# ============================================================
#
#   Loading base model: HuggingFaceTB/SmolLM2-360M-Instruct
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
#
# Loading weights:   0%|          | 0/290 [00:00<?, ?it/s]
# Loading weights:  43%|████▎     | 124/290 [00:00<00:00, 1237.23it/s]
# Loading weights: 100%|██████████| 290/290 [00:00<00:00, 1464.91it/s]
#   Loading adapter from HF: kon172verma/intent-classifier-experiments/v2.0/smollm2-360m_DoRA+_B_1k_20260826-035402
#   [  20/100]  running_acc=0.800
#   [  40/100]  running_acc=0.700
#   [  60/100]  running_acc=0.683
#   [  80/100]  running_acc=0.662
#   [ 100/100]  running_acc=0.630
#   Report pushed  : kon172verma/intent-classifier-experiments/reports/v2.0/doraplus/reports_validation/smollm2-360m_B_1k_val_20260826_094933.json
#
#   Accuracy   : 0.6300  (63/100)
#   Avg latency: 225.1 ms
#   Peak memory: 782 MB
#   Report     : /content/intent-classifier/finetune_DoRAplus/reports_validation/smollm2-360m_B_1k_val_20260826_094933.json
#
# ────────────────────────────────────────────────────────────
#   VAL    [3/20] smollm2-360m_C_1k
# ────────────────────────────────────────────────────────────
# Traceback (most recent call last):
#   File "/content/intent-classifier/finetune_DoRAplus/src/doraplus_validate.py", line 28, in <module>
#     run_validate_wrapper(
#     ~~~~~~~~~~~~~~~~~~~~^
#         __file__,
#         ^^^^^^^^^
#         technique="DoRA+",
#         ^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/content/intent-classifier/finetune_lib/wrappers.py", line 95, in run_validate_wrapper
#     lora_validate.validate_main(**kwargs)
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^
#   File "/content/intent-classifier/finetune_LoRA/src/lora_validate.py", line 240, in validate_main
#     raise ValueError(
#     ...<2 lines>...
#     )
# ValueError: No experiment found in EXPERIMENTS.jsonl for DoRA+/smollm2-360m_C_1k (version=v2.0). Pass --timestamp explicitly or use --local.
#
#   [ERROR] Exited with code 1
#
# ────────────────────────────────────────────────────────────
#   VAL    [4/20] smollm2-360m_D_1k
# ────────────────────────────────────────────────────────────
#
# ============================================================
#   DoRA+ Evaluation — smollm2-360m_D_1k
#   Split    : val  (100 examples)
#   Source   : kon172verma/intent-classifier-experiments/v2.0/smollm2-360m_DoRA+_D_1k_20260826-041121
#   Device   : cuda
# ============================================================
#
#   Loading base model: HuggingFaceTB/SmolLM2-360M-Instruct
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
#
# Loading weights:   0%|          | 0/290 [00:00<?, ?it/s]
# Loading weights:  53%|█████▎    | 154/290 [00:00<00:00, 1533.33it/s]
# Loading weights: 100%|██████████| 290/290 [00:00<00:00, 1599.13it/s]
#   Loading adapter from HF: kon172verma/intent-classifier-experiments/v2.0/smollm2-360m_DoRA+_D_1k_20260826-041121
#   [  20/100]  running_acc=0.750
#   [  40/100]  running_acc=0.700
#   [  60/100]  running_acc=0.650
#   [  80/100]  running_acc=0.650
#   [ 100/100]  running_acc=0.620
#   Report pushed  : kon172verma/intent-classifier-experiments/reports/v2.0/doraplus/reports_validation/smollm2-360m_D_1k_val_20260826_095040.json
#
#   Accuracy   : 0.6200  (62/100)
#   Avg latency: 327.6 ms
#   Peak memory: 876 MB
#   Report     : /content/intent-classifier/finetune_DoRAplus/reports_validation/smollm2-360m_D_1k_val_20260826_095040.json
#
# ────────────────────────────────────────────────────────────
#   VAL    [5/20] qwen2.5-0.5b_A_1k
# ────────────────────────────────────────────────────────────
#
# ============================================================
#   DoRA+ Evaluation — qwen2.5-0.5b_A_1k
#   Split    : val  (100 examples)
#   Source   : kon172verma/intent-classifier-experiments/v2.0/qwen2.5-0.5b_DoRA+_A_1k_20260826-041738
#   Device   : cuda
# ============================================================
#
#   Loading base model: Qwen/Qwen2.5-0.5B-Instruct
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
#
# Loading weights:   0%|          | 0/290 [00:00<?, ?it/s]
# Loading weights:  26%|██▌       | 76/290 [00:00<00:00, 752.26it/s]
# Loading weights:  72%|███████▏  | 208/290 [00:00<00:00, 1081.83it/s]
# Loading weights: 100%|██████████| 290/290 [00:00<00:00, 1110.08it/s]
#   Loading adapter from HF: kon172verma/intent-classifier-experiments/v2.0/qwen2.5-0.5b_DoRA+_A_1k_20260826-041738
#   [  20/100]  running_acc=0.950
#   [  40/100]  running_acc=0.850
#   [  60/100]  running_acc=0.850
#   [  80/100]  running_acc=0.863
#   [ 100/100]  running_acc=0.850
#   Report pushed  : kon172verma/intent-classifier-experiments/reports/v2.0/doraplus/reports_validation/qwen2.5-0.5b_A_1k_val_20260826_095113.json
#
#   Accuracy   : 0.8500  (85/100)
#   Avg latency: 118.0 ms
#   Peak memory: 992 MB
#   Report     : /content/intent-classifier/finetune_DoRAplus/reports_validation/qwen2.5-0.5b_A_1k_val_20260826_095113.json
#
# ────────────────────────────────────────────────────────────
#   VAL    [6/20] qwen2.5-0.5b_B_1k
# ────────────────────────────────────────────────────────────
#
# ============================================================
#   DoRA+ Evaluation — qwen2.5-0.5b_B_1k
#   Split    : val  (100 examples)
#   Source   : kon172verma/intent-classifier-experiments/v2.0/qwen2.5-0.5b_DoRA+_B_1k_20260826-042442
#   Device   : cuda
# ============================================================
#
#   Loading base model: Qwen/Qwen2.5-0.5B-Instruct
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
#
# Loading weights:   0%|          | 0/290 [00:00<?, ?it/s]
# Loading weights:  26%|██▌       | 75/290 [00:00<00:00, 748.59it/s]
# Loading weights:  72%|███████▏  | 208/290 [00:00<00:00, 1083.40it/s]
# Loading weights: 100%|██████████| 290/290 [00:00<00:00, 1095.14it/s]
#   Loading adapter from HF: kon172verma/intent-classifier-experiments/v2.0/qwen2.5-0.5b_DoRA+_B_1k_20260826-042442
#   [  20/100]  running_acc=0.950
#   [  40/100]  running_acc=0.900
#   [  60/100]  running_acc=0.867
#   [  80/100]  running_acc=0.875
#   [ 100/100]  running_acc=0.880
#   Report pushed  : kon172verma/intent-classifier-experiments/reports/v2.0/doraplus/reports_validation/qwen2.5-0.5b_B_1k_val_20260826_095152.json
#
#   Accuracy   : 0.8800  (88/100)
#   Avg latency: 175.2 ms
#   Peak memory: 998 MB
#   Report     : /content/intent-classifier/finetune_DoRAplus/reports_validation/qwen2.5-0.5b_B_1k_val_20260826_095152.json
#
# ────────────────────────────────────────────────────────────
#   VAL    [7/20] qwen2.5-0.5b_C_1k
# ────────────────────────────────────────────────────────────
# Traceback (most recent call last):
#   File "/content/intent-classifier/finetune_DoRAplus/src/doraplus_validate.py", line 28, in <module>
#     run_validate_wrapper(
#     ~~~~~~~~~~~~~~~~~~~~^
#         __file__,
#         ^^^^^^^^^
#         technique="DoRA+",
#         ^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/content/intent-classifier/finetune_lib/wrappers.py", line 95, in run_validate_wrapper
#     lora_validate.validate_main(**kwargs)
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^
#   File "/content/intent-classifier/finetune_LoRA/src/lora_validate.py", line 240, in validate_main
#     raise ValueError(
#     ...<2 lines>...
#     )
# ValueError: No experiment found in EXPERIMENTS.jsonl for DoRA+/qwen2.5-0.5b_C_1k (version=v2.0). Pass --timestamp explicitly or use --local.
#
#   [ERROR] Exited with code 1
#
# ────────────────────────────────────────────────────────────
#   VAL    [8/20] qwen2.5-0.5b_D_1k
# ────────────────────────────────────────────────────────────
#
# ============================================================
#   DoRA+ Evaluation — qwen2.5-0.5b_D_1k
#   Split    : val  (100 examples)
#   Source   : kon172verma/intent-classifier-experiments/v2.0/qwen2.5-0.5b_DoRA+_D_1k_20260826-044049
#   Device   : cuda
# ============================================================
#
#   Loading base model: Qwen/Qwen2.5-0.5B-Instruct
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
#
# Loading weights:   0%|          | 0/290 [00:00<?, ?it/s]
# Loading weights:  26%|██▌       | 76/290 [00:00<00:00, 751.28it/s]
# Loading weights:  72%|███████▏  | 209/290 [00:00<00:00, 1078.47it/s]
# Loading weights: 100%|██████████| 290/290 [00:00<00:00, 1094.10it/s]
#   Loading adapter from HF: kon172verma/intent-classifier-experiments/v2.0/qwen2.5-0.5b_DoRA+_D_1k_20260826-044049
#   [  20/100]  running_acc=0.900
#   [  40/100]  running_acc=0.875
#   [  60/100]  running_acc=0.833
#   [  80/100]  running_acc=0.825
#   [ 100/100]  running_acc=0.810
#   Report pushed  : kon172verma/intent-classifier-experiments/reports/v2.0/doraplus/reports_validation/qwen2.5-0.5b_D_1k_val_20260826_095251.json
#
#   Accuracy   : 0.8100  (81/100)
#   Avg latency: 247.9 ms
#   Peak memory: 1166 MB
#   Report     : /content/intent-classifier/finetune_DoRAplus/reports_validation/qwen2.5-0.5b_D_1k_val_20260826_095251.json
#
# ────────────────────────────────────────────────────────────
#   VAL    [9/20] qwen3-0.6b_A_1k
# ────────────────────────────────────────────────────────────
#
# ============================================================
#   DoRA+ Evaluation — qwen3-0.6b_A_1k
#   Split    : val  (100 examples)
#   Source   : kon172verma/intent-classifier-experiments/v2.0/qwen3-0.6b_DoRA+_A_1k_20260826-045211
#   Device   : cuda
# ============================================================
#
#   Loading base model: Qwen/Qwen3-0.6B
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
#
# Loading weights:   0%|          | 0/311 [00:00<?, ?it/s]
# Loading weights:   0%|          | 1/311 [00:00<00:45,  6.74it/s]
# Loading weights:  41%|████      | 127/311 [00:00<00:00, 620.42it/s]
# Loading weights:  83%|████████▎ | 257/311 [00:00<00:00, 899.97it/s]
# Loading weights: 100%|██████████| 311/311 [00:00<00:00, 793.60it/s]
#   Loading adapter from HF: kon172verma/intent-classifier-experiments/v2.0/qwen3-0.6b_DoRA+_A_1k_20260826-045211
#   [  20/100]  running_acc=1.000
#   [  40/100]  running_acc=0.975
#   [  60/100]  running_acc=0.983
#   [  80/100]  running_acc=0.988
#   [ 100/100]  running_acc=0.990
#   Report pushed  : kon172verma/intent-classifier-experiments/reports/v2.0/doraplus/reports_validation/qwen3-0.6b_A_1k_val_20260826_095328.json
#
#   Accuracy   : 0.9900  (99/100)
#   Avg latency: 149.3 ms
#   Peak memory: 1289 MB
#   Report     : /content/intent-classifier/finetune_DoRAplus/reports_validation/qwen3-0.6b_A_1k_val_20260826_095328.json
#
# ────────────────────────────────────────────────────────────
#   VAL    [10/20] qwen3-0.6b_B_1k
# ────────────────────────────────────────────────────────────
#
# ============================================================
#   DoRA+ Evaluation — qwen3-0.6b_B_1k
#   Split    : val  (100 examples)
#   Source   : kon172verma/intent-classifier-experiments/v2.0/qwen3-0.6b_DoRA+_B_1k_20260826-050540
#   Device   : cuda
# ============================================================
#
#   Loading base model: Qwen/Qwen3-0.6B
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
#
# Loading weights:   0%|          | 0/311 [00:00<?, ?it/s]
# Loading weights:   1%|          | 2/311 [00:00<00:19, 15.92it/s]
# Loading weights:  41%|████      | 126/311 [00:00<00:00, 662.44it/s]
# Loading weights:  79%|███████▉  | 247/311 [00:00<00:00, 895.35it/s]
# Loading weights: 100%|██████████| 311/311 [00:00<00:00, 829.70it/s]
#   Loading adapter from HF: kon172verma/intent-classifier-experiments/v2.0/qwen3-0.6b_DoRA+_B_1k_20260826-050540
#   [  20/100]  running_acc=1.000
#   [  40/100]  running_acc=0.975
#   [  60/100]  running_acc=0.967
#   [  80/100]  running_acc=0.975
#   [ 100/100]  running_acc=0.970
#   Report pushed  : kon172verma/intent-classifier-experiments/reports/v2.0/doraplus/reports_validation/qwen3-0.6b_B_1k_val_20260826_095412.json
#
#   Accuracy   : 0.9700  (97/100)
#   Avg latency: 211.5 ms
#   Peak memory: 1304 MB
#   Report     : /content/intent-classifier/finetune_DoRAplus/reports_validation/qwen3-0.6b_B_1k_val_20260826_095412.json
#
# ────────────────────────────────────────────────────────────
#   VAL    [11/20] qwen3-0.6b_C_1k
# ────────────────────────────────────────────────────────────
# Traceback (most recent call last):
#   File "/content/intent-classifier/finetune_DoRAplus/src/doraplus_validate.py", line 28, in <module>
#     run_validate_wrapper(
#     ~~~~~~~~~~~~~~~~~~~~^
#         __file__,
#         ^^^^^^^^^
#         technique="DoRA+",
#         ^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/content/intent-classifier/finetune_lib/wrappers.py", line 95, in run_validate_wrapper
#     lora_validate.validate_main(**kwargs)
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^
#   File "/content/intent-classifier/finetune_LoRA/src/lora_validate.py", line 240, in validate_main
#     raise ValueError(
#     ...<2 lines>...
#     )
# ValueError: No experiment found in EXPERIMENTS.jsonl for DoRA+/qwen3-0.6b_C_1k (version=v2.0). Pass --timestamp explicitly or use --local.
#
#   [ERROR] Exited with code 1
#
# ────────────────────────────────────────────────────────────
#   VAL    [12/20] qwen3-0.6b_D_1k
# ────────────────────────────────────────────────────────────
#
# ============================================================
#   DoRA+ Evaluation — qwen3-0.6b_D_1k
#   Split    : val  (100 examples)
#   Source   : kon172verma/intent-classifier-experiments/v2.0/qwen3-0.6b_DoRA+_D_1k_20260826-052401
#   Device   : cuda
# ============================================================
#
#   Loading base model: Qwen/Qwen3-0.6B
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
#
# Loading weights:   0%|          | 0/311 [00:00<?, ?it/s]
# Loading weights:   0%|          | 1/311 [00:00<00:38,  8.04it/s]
# Loading weights:  43%|████▎     | 133/311 [00:00<00:00, 706.06it/s]
# Loading weights:  84%|████████▍ | 262/311 [00:00<00:00, 957.81it/s]
# Loading weights: 100%|██████████| 311/311 [00:00<00:00, 854.22it/s]
#   Loading adapter from HF: kon172verma/intent-classifier-experiments/v2.0/qwen3-0.6b_DoRA+_D_1k_20260826-052401
#   [  20/100]  running_acc=1.000
#   [  40/100]  running_acc=0.975
#   [  60/100]  running_acc=0.983
#   [  80/100]  running_acc=0.988
#   [ 100/100]  running_acc=0.990
#   Report pushed  : kon172verma/intent-classifier-experiments/reports/v2.0/doraplus/reports_validation/qwen3-0.6b_D_1k_val_20260826_095517.json
#
#   Accuracy   : 0.9900  (99/100)
#   Avg latency: 300.9 ms
#   Peak memory: 1394 MB
#   Report     : /content/intent-classifier/finetune_DoRAplus/reports_validation/qwen3-0.6b_D_1k_val_20260826_095517.json
#
# ────────────────────────────────────────────────────────────
#   VAL    [13/20] llama3.2-1b_A_1k
# ────────────────────────────────────────────────────────────
#
# ============================================================
#   DoRA+ Evaluation — llama3.2-1b_A_1k
#   Split    : val  (100 examples)
#   Source   : kon172verma/intent-classifier-experiments/v2.0/llama3.2-1b_DoRA+_A_1k_20260826-053607
#   Device   : cuda
# ============================================================
#
#   Loading base model: meta-llama/Llama-3.2-1B-Instruct
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
#
# Loading weights:   0%|          | 0/146 [00:00<?, ?it/s]
# Loading weights:   1%|          | 1/146 [00:00<00:17,  8.48it/s]
# Loading weights:  21%|██        | 30/146 [00:00<00:00, 160.21it/s]
# Loading weights:  40%|███▉      | 58/146 [00:00<00:00, 209.87it/s]
# Loading weights:  59%|█████▉    | 86/146 [00:00<00:00, 233.82it/s]
# Loading weights:  81%|████████  | 118/146 [00:00<00:00, 263.92it/s]
# Loading weights: 100%|██████████| 146/146 [00:00<00:00, 235.45it/s]
#   Loading adapter from HF: kon172verma/intent-classifier-experiments/v2.0/llama3.2-1b_DoRA+_A_1k_20260826-053607
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer TokenizersBackend. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
#   [  20/100]  running_acc=0.950
#   [  40/100]  running_acc=0.950
#   [  60/100]  running_acc=0.933
#   [  80/100]  running_acc=0.950
#   [ 100/100]  running_acc=0.960
#   Report pushed  : kon172verma/intent-classifier-experiments/reports/v2.0/doraplus/reports_validation/llama3.2-1b_A_1k_val_20260826_095548.json
#
#   Accuracy   : 0.9600  (96/100)
#   Avg latency: 85.9 ms
#   Peak memory: 2478 MB
#   Report     : /content/intent-classifier/finetune_DoRAplus/reports_validation/llama3.2-1b_A_1k_val_20260826_095548.json
#
# ────────────────────────────────────────────────────────────
#   VAL    [14/20] llama3.2-1b_B_1k
# ────────────────────────────────────────────────────────────
#
# ============================================================
#   DoRA+ Evaluation — llama3.2-1b_B_1k
#   Split    : val  (100 examples)
#   Source   : kon172verma/intent-classifier-experiments/v2.0/llama3.2-1b_DoRA+_B_1k_20260826-055029
#   Device   : cuda
# ============================================================
#
#   Loading base model: meta-llama/Llama-3.2-1B-Instruct
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
#
# Loading weights:   0%|          | 0/146 [00:00<?, ?it/s]
# Loading weights:   1%|          | 1/146 [00:00<00:16,  8.56it/s]
# Loading weights:  21%|██        | 30/146 [00:00<00:00, 160.72it/s]
# Loading weights:  40%|███▉      | 58/146 [00:00<00:00, 210.23it/s]
# Loading weights:  59%|█████▉    | 86/146 [00:00<00:00, 233.94it/s]
# Loading weights:  82%|████████▏ | 120/146 [00:00<00:00, 263.52it/s]
# Loading weights: 100%|██████████| 146/146 [00:00<00:00, 235.60it/s]
#   Loading adapter from HF: kon172verma/intent-classifier-experiments/v2.0/llama3.2-1b_DoRA+_B_1k_20260826-055029
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer TokenizersBackend. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
#   [  20/100]  running_acc=1.000
#   [  40/100]  running_acc=0.950
#   [  60/100]  running_acc=0.967
#   [  80/100]  running_acc=0.975
#   [ 100/100]  running_acc=0.970
#   Report pushed  : kon172verma/intent-classifier-experiments/reports/v2.0/doraplus/reports_validation/llama3.2-1b_B_1k_val_20260826_095624.json
#
#   Accuracy   : 0.9700  (97/100)
#   Avg latency: 119.1 ms
#   Peak memory: 2496 MB
#   Report     : /content/intent-classifier/finetune_DoRAplus/reports_validation/llama3.2-1b_B_1k_val_20260826_095624.json
#
# ────────────────────────────────────────────────────────────
#   VAL    [15/20] llama3.2-1b_C_1k
# ────────────────────────────────────────────────────────────
#
# ============================================================
#   DoRA+ Evaluation — llama3.2-1b_C_1k
#   Split    : val  (100 examples)
#   Source   : kon172verma/intent-classifier-experiments/v2.0/llama3.2-1b_DoRA+_C_1k_20260826-062643
#   Device   : cuda
# ============================================================
#
#   Loading base model: meta-llama/Llama-3.2-1B-Instruct
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
#
# Loading weights:   0%|          | 0/146 [00:00<?, ?it/s]
# Loading weights:   1%|          | 1/146 [00:00<00:17,  8.44it/s]
# Loading weights:  21%|██        | 30/146 [00:00<00:00, 159.88it/s]
# Loading weights:  40%|███▉      | 58/146 [00:00<00:00, 209.56it/s]
# Loading weights:  58%|█████▊    | 84/146 [00:00<00:00, 226.58it/s]
# Loading weights:  81%|████████  | 118/146 [00:00<00:00, 265.94it/s]
# Loading weights: 100%|██████████| 146/146 [00:00<00:00, 234.60it/s]
#   Loading adapter from HF: kon172verma/intent-classifier-experiments/v2.0/llama3.2-1b_DoRA+_C_1k_20260826-062643
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer TokenizersBackend. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
#   [  20/100]  running_acc=1.000
#   [  40/100]  running_acc=0.950
#   [  60/100]  running_acc=0.950
#   [  80/100]  running_acc=0.950
#   [ 100/100]  running_acc=0.960
#   Report pushed  : kon172verma/intent-classifier-experiments/reports/v2.0/doraplus/reports_validation/llama3.2-1b_C_1k_val_20260826_095734.json
#
#   Accuracy   : 0.9600  (96/100)
#   Avg latency: 449.4 ms
#   Peak memory: 2813 MB
#   Report     : /content/intent-classifier/finetune_DoRAplus/reports_validation/llama3.2-1b_C_1k_val_20260826_095734.json
#
# ────────────────────────────────────────────────────────────
#   VAL    [16/20] llama3.2-1b_D_1k
# ────────────────────────────────────────────────────────────
#
# ============================================================
#   DoRA+ Evaluation — llama3.2-1b_D_1k
#   Split    : val  (100 examples)
#   Source   : kon172verma/intent-classifier-experiments/v2.0/llama3.2-1b_DoRA+_D_1k_20260826-070251
#   Device   : cuda
# ============================================================
#
#   Loading base model: meta-llama/Llama-3.2-1B-Instruct
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
#
# Loading weights:   0%|          | 0/146 [00:00<?, ?it/s]
# Loading weights:   1%|          | 1/146 [00:00<00:16,  8.61it/s]
# Loading weights:  21%|██        | 30/146 [00:00<00:00, 161.42it/s]
# Loading weights:  40%|███▉      | 58/146 [00:00<00:00, 211.40it/s]
# Loading weights:  59%|█████▉    | 86/146 [00:00<00:00, 235.05it/s]
# Loading weights:  82%|████████▏ | 119/146 [00:00<00:00, 253.78it/s]
# Loading weights: 100%|██████████| 146/146 [00:00<00:00, 236.73it/s]
#   Loading adapter from HF: kon172verma/intent-classifier-experiments/v2.0/llama3.2-1b_DoRA+_D_1k_20260826-070251
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer TokenizersBackend. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
#   [  20/100]  running_acc=0.950
#   [  40/100]  running_acc=0.925
#   [  60/100]  running_acc=0.917
#   [  80/100]  running_acc=0.938
#   [ 100/100]  running_acc=0.940
#   Report pushed  : kon172verma/intent-classifier-experiments/reports/v2.0/doraplus/reports_validation/llama3.2-1b_D_1k_val_20260826_095847.json
#
#   Accuracy   : 0.9400  (94/100)
#   Avg latency: 454.8 ms
#   Peak memory: 2856 MB
#   Report     : /content/intent-classifier/finetune_DoRAplus/reports_validation/llama3.2-1b_D_1k_val_20260826_095847.json
#
# ────────────────────────────────────────────────────────────
#   VAL    [17/20] smollm2-1.7b_A_1k
# ────────────────────────────────────────────────────────────
#
# ============================================================
#   DoRA+ Evaluation — smollm2-1.7b_A_1k
#   Split    : val  (100 examples)
#   Source   : kon172verma/intent-classifier-experiments/v2.0/smollm2-1.7b_DoRA+_A_1k_20260826-072348
#   Device   : cuda
# ============================================================
#
#   Loading base model: HuggingFaceTB/SmolLM2-1.7B-Instruct
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
#
# Loading weights:   0%|          | 0/218 [00:00<?, ?it/s]
# Loading weights:  10%|▉         | 21/218 [00:00<00:01, 194.26it/s]
# Loading weights:  22%|██▏       | 48/218 [00:00<00:00, 234.95it/s]
# Loading weights:  34%|███▍      | 75/218 [00:00<00:00, 246.90it/s]
# Loading weights:  47%|████▋     | 102/218 [00:00<00:00, 252.63it/s]
# Loading weights:  59%|█████▉    | 129/218 [00:00<00:00, 255.23it/s]
# Loading weights:  72%|███████▏  | 156/218 [00:00<00:00, 256.81it/s]
# Loading weights:  84%|████████▍ | 183/218 [00:00<00:00, 258.09it/s]
# Loading weights:  96%|█████████▋| 210/218 [00:00<00:00, 259.73it/s]
# Loading weights: 100%|██████████| 218/218 [00:00<00:00, 254.63it/s]
#   Loading adapter from HF: kon172verma/intent-classifier-experiments/v2.0/smollm2-1.7b_DoRA+_A_1k_20260826-072348
#   [  20/100]  running_acc=1.000
#   [  40/100]  running_acc=0.975
#   [  60/100]  running_acc=0.950
#   [  80/100]  running_acc=0.963
#   [ 100/100]  running_acc=0.960
#   Report pushed  : kon172verma/intent-classifier-experiments/reports/v2.0/doraplus/reports_validation/smollm2-1.7b_A_1k_val_20260826_095921.json
#
#   Accuracy   : 0.9600  (96/100)
#   Avg latency: 127.5 ms
#   Peak memory: 3539 MB
#   Report     : /content/intent-classifier/finetune_DoRAplus/reports_validation/smollm2-1.7b_A_1k_val_20260826_095921.json
#
# ────────────────────────────────────────────────────────────
#   VAL    [18/20] smollm2-1.7b_B_1k
# ────────────────────────────────────────────────────────────
#
# ============================================================
#   DoRA+ Evaluation — smollm2-1.7b_B_1k
#   Split    : val  (100 examples)
#   Source   : kon172verma/intent-classifier-experiments/v2.0/smollm2-1.7b_DoRA+_B_1k_20260826-074958
#   Device   : cuda
# ============================================================
#
#   Loading base model: HuggingFaceTB/SmolLM2-1.7B-Instruct
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
#
# Loading weights:   0%|          | 0/218 [00:00<?, ?it/s]
# Loading weights:  10%|▉         | 21/218 [00:00<00:00, 199.99it/s]
# Loading weights:  22%|██▏       | 48/218 [00:00<00:00, 235.69it/s]
# Loading weights:  34%|███▍      | 75/218 [00:00<00:00, 247.29it/s]
# Loading weights:  47%|████▋     | 102/218 [00:00<00:00, 252.38it/s]
# Loading weights:  59%|█████▉    | 129/218 [00:00<00:00, 255.63it/s]
# Loading weights:  72%|███████▏  | 156/218 [00:00<00:00, 257.70it/s]
# Loading weights:  84%|████████▍ | 183/218 [00:00<00:00, 258.89it/s]
# Loading weights:  96%|█████████▋| 210/218 [00:00<00:00, 260.16it/s]
# Loading weights: 100%|██████████| 218/218 [00:00<00:00, 255.27it/s]
#   Loading adapter from HF: kon172verma/intent-classifier-experiments/v2.0/smollm2-1.7b_DoRA+_B_1k_20260826-074958
#   [  20/100]  running_acc=1.000
#   [  40/100]  running_acc=0.975
#   [  60/100]  running_acc=0.933
#   [  80/100]  running_acc=0.950
#   [ 100/100]  running_acc=0.950
#   Report pushed  : kon172verma/intent-classifier-experiments/reports/v2.0/doraplus/reports_validation/smollm2-1.7b_B_1k_val_20260826_100002.json
#
#   Accuracy   : 0.9500  (95/100)
#   Avg latency: 186.1 ms
#   Peak memory: 3564 MB
#   Report     : /content/intent-classifier/finetune_DoRAplus/reports_validation/smollm2-1.7b_B_1k_val_20260826_100002.json
#
# ────────────────────────────────────────────────────────────
#   VAL    [19/20] smollm2-1.7b_C_1k
# ────────────────────────────────────────────────────────────
#
# ============================================================
#   DoRA+ Evaluation — smollm2-1.7b_C_1k
#   Split    : val  (100 examples)
#   Source   : kon172verma/intent-classifier-experiments/v2.0/smollm2-1.7b_DoRA+_C_1k_20260826-084923
#   Device   : cuda
# ============================================================
#
#   Loading base model: HuggingFaceTB/SmolLM2-1.7B-Instruct
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
#
# Loading weights:   0%|          | 0/218 [00:00<?, ?it/s]
# Loading weights:   6%|▋         | 14/218 [00:00<00:01, 130.65it/s]
# Loading weights:  19%|█▉        | 41/218 [00:00<00:00, 205.77it/s]
# Loading weights:  31%|███       | 68/218 [00:00<00:00, 230.47it/s]
# Loading weights:  44%|████▎     | 95/218 [00:00<00:00, 242.15it/s]
# Loading weights:  56%|█████▌    | 122/218 [00:00<00:00, 247.97it/s]
# Loading weights:  68%|██████▊   | 149/218 [00:00<00:00, 252.56it/s]
# Loading weights:  81%|████████  | 176/218 [00:00<00:00, 253.49it/s]
# Loading weights:  93%|█████████▎| 203/218 [00:00<00:00, 254.99it/s]
# Loading weights: 100%|██████████| 218/218 [00:00<00:00, 247.78it/s]
#   Loading adapter from HF: kon172verma/intent-classifier-experiments/v2.0/smollm2-1.7b_DoRA+_C_1k_20260826-084923
#   [  20/100]  running_acc=1.000
#   [  40/100]  running_acc=0.975
#   [  60/100]  running_acc=0.967
#   [  80/100]  running_acc=0.975
#   [ 100/100]  running_acc=0.970
#   Report pushed  : kon172verma/intent-classifier-experiments/reports/v2.0/doraplus/reports_validation/smollm2-1.7b_C_1k_val_20260826_100138.json
#
#   Accuracy   : 0.9700  (97/100)
#   Avg latency: 706.5 ms
#   Peak memory: 3900 MB
#   Report     : /content/intent-classifier/finetune_DoRAplus/reports_validation/smollm2-1.7b_C_1k_val_20260826_100138.json
#
# ────────────────────────────────────────────────────────────
#   VAL    [20/20] smollm2-1.7b_D_1k
# ────────────────────────────────────────────────────────────
#
# ============================================================
#   DoRA+ Evaluation — smollm2-1.7b_D_1k
#   Split    : val  (100 examples)
#   Source   : kon172verma/intent-classifier-experiments/v2.0/smollm2-1.7b_DoRA+_D_1k_20260826-094624
#   Device   : cuda
# ============================================================
#
#   Loading base model: HuggingFaceTB/SmolLM2-1.7B-Instruct
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
#
# Loading weights:   0%|          | 0/218 [00:00<?, ?it/s]
# Loading weights:   6%|▌         | 13/218 [00:00<00:01, 128.05it/s]
# Loading weights:  18%|█▊        | 40/218 [00:00<00:00, 206.80it/s]
# Loading weights:  31%|███       | 67/218 [00:00<00:00, 232.68it/s]
# Loading weights:  43%|████▎     | 94/218 [00:00<00:00, 243.35it/s]
# Loading weights:  56%|█████▌    | 121/218 [00:00<00:00, 248.52it/s]
# Loading weights:  68%|██████▊   | 148/218 [00:00<00:00, 253.12it/s]
# Loading weights:  80%|████████  | 175/218 [00:00<00:00, 255.26it/s]
# Loading weights:  93%|█████████▎| 202/218 [00:00<00:00, 257.75it/s]
# Loading weights: 100%|██████████| 218/218 [00:00<00:00, 248.44it/s]
#   Loading adapter from HF: kon172verma/intent-classifier-experiments/v2.0/smollm2-1.7b_DoRA+_D_1k_20260826-094624
#   [  20/100]  running_acc=1.000
#   [  40/100]  running_acc=0.975
#   [  60/100]  running_acc=0.967
#   [  80/100]  running_acc=0.963
#   [ 100/100]  running_acc=0.960
#   Report pushed  : kon172verma/intent-classifier-experiments/reports/v2.0/doraplus/reports_validation/smollm2-1.7b_D_1k_val_20260826_100315.json
#
#   Accuracy   : 0.9600  (96/100)
#   Avg latency: 714.2 ms
#   Peak memory: 3969 MB
#   Report     : /content/intent-classifier/finetune_DoRAplus/reports_validation/smollm2-1.7b_D_1k_val_20260826_100315.json
#
# ============================================================
#   EXPERIMENT RUNNER COMPLETE
#   Completed at: 2026-08-26 10:03:19
#
#   smollm2-360m_A_1k                    train=OK  val=OK
#   smollm2-360m_B_1k                    train=OK  val=OK
#   smollm2-360m_C_1k                    train=OK  val=FAIL
#   smollm2-360m_D_1k                    train=OK  val=OK
#   qwen2.5-0.5b_A_1k                    train=OK  val=OK
#   qwen2.5-0.5b_B_1k                    train=OK  val=OK
#   qwen2.5-0.5b_C_1k                    train=OK  val=FAIL
#   qwen2.5-0.5b_D_1k                    train=OK  val=OK
#   qwen3-0.6b_A_1k                      train=OK  val=OK
#   qwen3-0.6b_B_1k                      train=OK  val=OK
#   qwen3-0.6b_C_1k                      train=OK  val=FAIL
#   qwen3-0.6b_D_1k                      train=OK  val=OK
#   llama3.2-1b_A_1k                     train=OK  val=OK
#   llama3.2-1b_B_1k                     train=OK  val=OK
#   llama3.2-1b_C_1k                     train=OK  val=OK
#   llama3.2-1b_D_1k                     train=OK  val=OK
#   smollm2-1.7b_A_1k                    train=OK  val=OK
#   smollm2-1.7b_B_1k                    train=OK  val=OK
#   smollm2-1.7b_C_1k                    train=OK  val=OK
#   smollm2-1.7b_D_1k                    train=OK  val=OK
# ============================================================
#
#
# Validation complete in 912s

# %% [markdown]
# ## 10. Test evaluation (locked)
#
# Run this cell deliberately **once** after reviewing validation results.
#
# Reports saved to `finetune_DoRAplus/reports_test/`.

# %%
import subprocess
import sys
import time

for model_key in MODELS_TO_RUN:
    for cfg in CONFIGS_TO_RUN:
        run_tag = f"{model_key}_{cfg}_{DATASET_SIZE}"
        cmd = [
            sys.executable, "-u", f"{SRC_DIR}/doraplus_validate.py",
            "--model",        model_key,
            "--lora-config",  cfg,
            "--dataset-size", DATASET_SIZE,
            "--split",        "test",
            "--device",       DEVICE,
        ]
        print(f"\n  Testing {run_tag}...")
        t0 = time.time()
        proc = subprocess.Popen(
            cmd,
            stdout=subprocess.PIPE,
            stderr=subprocess.STDOUT,
            text=True,
            bufsize=1,
            cwd=REPO_DIR,
        )
        _buf: list[str] = []
        while True:
            ch = proc.stdout.read(1)
            if not ch:
                if _buf:
                    line = "".join(_buf)
                    if not line.startswith("Failed to load "):
                        print(line, end="", flush=True)
                break
            _buf.append(ch)
            if ch in ("\r", "\n"):
                line = "".join(_buf)
                if not line.startswith("Failed to load "):
                    print(line, end="", flush=True)
                _buf = []
        proc.stdout.close()
        proc.wait()
        print(f"  {'OK' if proc.returncode == 0 else 'FAILED'} in {time.time()-t0:.0f}s")
# Out:
#   Testing smollm2-360m_A_1k...
#
# ============================================================
#   DoRA+ Evaluation — smollm2-360m_A_1k
#   Split    : test  (100 examples)
#   Source   : kon172verma/intent-classifier-experiments/v2.0/smollm2-360m_DoRA+_A_1k_20260826-034416
#   Device   : cuda
# ============================================================
#
#   Loading base model: HuggingFaceTB/SmolLM2-360M-Instruct
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
#
# Loading weights:   0%|          | 0/290 [00:00<?, ?it/s]
# Loading weights:  45%|████▍     | 130/290 [00:00<00:00, 1287.23it/s]
# Loading weights: 100%|██████████| 290/290 [00:00<00:00, 1463.43it/s]
#   Loading adapter from HF: kon172verma/intent-classifier-experiments/v2.0/smollm2-360m_DoRA+_A_1k_20260826-034416
#   [  20/100]  running_acc=0.700
#   [  40/100]  running_acc=0.700
#   [  60/100]  running_acc=0.683
#   [  80/100]  running_acc=0.725
#   [ 100/100]  running_acc=0.720
#   Report pushed  : kon172verma/intent-classifier-experiments/reports/v2.0/doraplus/reports_test/smollm2-360m_A_1k_test_20260826_100348.json
#
#   Accuracy   : 0.7200  (72/100)
#   Avg latency: 149.7 ms
#   Peak memory: 768 MB
#   Report     : /content/intent-classifier/finetune_DoRAplus/reports_test/smollm2-360m_A_1k_test_20260826_100348.json
#   OK in 31s
#
#   Testing smollm2-360m_B_1k...
#
# ============================================================
#   DoRA+ Evaluation — smollm2-360m_B_1k
#   Split    : test  (100 examples)
#   Source   : kon172verma/intent-classifier-experiments/v2.0/smollm2-360m_DoRA+_B_1k_20260826-035402
#   Device   : cuda
# ============================================================
#
#   Loading base model: HuggingFaceTB/SmolLM2-360M-Instruct
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
#
# Loading weights:   0%|          | 0/290 [00:00<?, ?it/s]
# Loading weights:  52%|█████▏    | 151/290 [00:00<00:00, 1507.70it/s]
# Loading weights: 100%|██████████| 290/290 [00:00<00:00, 1570.12it/s]
#   Loading adapter from HF: kon172verma/intent-classifier-experiments/v2.0/smollm2-360m_DoRA+_B_1k_20260826-035402
#   [  20/100]  running_acc=0.650
#   [  40/100]  running_acc=0.650
#   [  60/100]  running_acc=0.683
#   [  80/100]  running_acc=0.738
#   [ 100/100]  running_acc=0.710
#   Report pushed  : kon172verma/intent-classifier-experiments/reports/v2.0/doraplus/reports_test/smollm2-360m_B_1k_test_20260826_100426.json
#
#   Accuracy   : 0.7100  (71/100)
#   Avg latency: 219.5 ms
#   Peak memory: 782 MB
#   Report     : /content/intent-classifier/finetune_DoRAplus/reports_test/smollm2-360m_B_1k_test_20260826_100426.json
#   OK in 38s
#
#   Testing smollm2-360m_C_1k...
# Traceback (most recent call last):
#   File "/content/intent-classifier/finetune_DoRAplus/src/doraplus_validate.py", line 28, in <module>
#     run_validate_wrapper(
#     ~~~~~~~~~~~~~~~~~~~~^
#         __file__,
#         ^^^^^^^^^
#         technique="DoRA+",
#         ^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/content/intent-classifier/finetune_lib/wrappers.py", line 95, in run_validate_wrapper
#     lora_validate.validate_main(**kwargs)
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^
#   File "/content/intent-classifier/finetune_LoRA/src/lora_validate.py", line 240, in validate_main
#     raise ValueError(
#     ...<2 lines>...
#     )
# ValueError: No experiment found in EXPERIMENTS.jsonl for DoRA+/smollm2-360m_C_1k (version=v2.0). Pass --timestamp explicitly or use --local.
#   FAILED in 10s
#
#   Testing smollm2-360m_D_1k...
#
# ============================================================
#   DoRA+ Evaluation — smollm2-360m_D_1k
#   Split    : test  (100 examples)
#   Source   : kon172verma/intent-classifier-experiments/v2.0/smollm2-360m_DoRA+_D_1k_20260826-041121
#   Device   : cuda
# ============================================================
#
#   Loading base model: HuggingFaceTB/SmolLM2-360M-Instruct
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
#
# Loading weights:   0%|          | 0/290 [00:00<?, ?it/s]
# Loading weights:  59%|█████▊    | 170/290 [00:00<00:00, 1696.90it/s]
# Loading weights: 100%|██████████| 290/290 [00:00<00:00, 1692.28it/s]
#   Loading adapter from HF: kon172verma/intent-classifier-experiments/v2.0/smollm2-360m_DoRA+_D_1k_20260826-041121
#   [  20/100]  running_acc=0.600
#   [  40/100]  running_acc=0.625
#   [  60/100]  running_acc=0.633
#   [  80/100]  running_acc=0.675
#   [ 100/100]  running_acc=0.680
#   Report pushed  : kon172verma/intent-classifier-experiments/reports/v2.0/doraplus/reports_test/smollm2-360m_D_1k_test_20260826_100525.json
#
#   Accuracy   : 0.6800  (68/100)
#   Avg latency: 318.8 ms
#   Peak memory: 877 MB
#   Report     : /content/intent-classifier/finetune_DoRAplus/reports_test/smollm2-360m_D_1k_test_20260826_100525.json
#   OK in 48s
#
#   Testing qwen2.5-0.5b_A_1k...
#
# ============================================================
#   DoRA+ Evaluation — qwen2.5-0.5b_A_1k
#   Split    : test  (100 examples)
#   Source   : kon172verma/intent-classifier-experiments/v2.0/qwen2.5-0.5b_DoRA+_A_1k_20260826-041738
#   Device   : cuda
# ============================================================
#
#   Loading base model: Qwen/Qwen2.5-0.5B-Instruct
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
#
# Loading weights:   0%|          | 0/290 [00:00<?, ?it/s]
# Loading weights:  22%|██▏       | 64/290 [00:00<00:00, 619.33it/s]
# Loading weights:  68%|██████▊   | 197/290 [00:00<00:00, 1031.28it/s]
# Loading weights: 100%|██████████| 290/290 [00:00<00:00, 1074.99it/s]
#   Loading adapter from HF: kon172verma/intent-classifier-experiments/v2.0/qwen2.5-0.5b_DoRA+_A_1k_20260826-041738
#   [  20/100]  running_acc=0.900
#   [  40/100]  running_acc=0.900
#   [  60/100]  running_acc=0.850
#   [  80/100]  running_acc=0.863
#   [ 100/100]  running_acc=0.860
#   Report pushed  : kon172verma/intent-classifier-experiments/reports/v2.0/doraplus/reports_test/qwen2.5-0.5b_A_1k_test_20260826_100553.json
#
#   Accuracy   : 0.8600  (86/100)
#   Avg latency: 118.6 ms
#   Peak memory: 992 MB
#   Report     : /content/intent-classifier/finetune_DoRAplus/reports_test/qwen2.5-0.5b_A_1k_test_20260826_100553.json
#   OK in 29s
#
#   Testing qwen2.5-0.5b_B_1k...
#
# ============================================================
#   DoRA+ Evaluation — qwen2.5-0.5b_B_1k
#   Split    : test  (100 examples)
#   Source   : kon172verma/intent-classifier-experiments/v2.0/qwen2.5-0.5b_DoRA+_B_1k_20260826-042442
#   Device   : cuda
# ============================================================
#
#   Loading base model: Qwen/Qwen2.5-0.5B-Instruct
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
#
# Loading weights:   0%|          | 0/290 [00:00<?, ?it/s]
# Loading weights:  28%|██▊       | 81/290 [00:00<00:00, 805.89it/s]
# Loading weights:  74%|███████▍  | 216/290 [00:00<00:00, 1123.75it/s]
# Loading weights: 100%|██████████| 290/290 [00:00<00:00, 1133.31it/s]
#   Loading adapter from HF: kon172verma/intent-classifier-experiments/v2.0/qwen2.5-0.5b_DoRA+_B_1k_20260826-042442
#   [  20/100]  running_acc=0.900
#   [  40/100]  running_acc=0.900
#   [  60/100]  running_acc=0.900
#   [  80/100]  running_acc=0.912
#   [ 100/100]  running_acc=0.910
#   Report pushed  : kon172verma/intent-classifier-experiments/reports/v2.0/doraplus/reports_test/qwen2.5-0.5b_B_1k_test_20260826_100627.json
#
#   Accuracy   : 0.9100  (91/100)
#   Avg latency: 170.2 ms
#   Peak memory: 999 MB
#   Report     : /content/intent-classifier/finetune_DoRAplus/reports_test/qwen2.5-0.5b_B_1k_test_20260826_100627.json
#   OK in 34s
#
#   Testing qwen2.5-0.5b_C_1k...
# Traceback (most recent call last):
#   File "/content/intent-classifier/finetune_DoRAplus/src/doraplus_validate.py", line 28, in <module>
#     run_validate_wrapper(
#     ~~~~~~~~~~~~~~~~~~~~^
#         __file__,
#         ^^^^^^^^^
#         technique="DoRA+",
#         ^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/content/intent-classifier/finetune_lib/wrappers.py", line 95, in run_validate_wrapper
#     lora_validate.validate_main(**kwargs)
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^
#   File "/content/intent-classifier/finetune_LoRA/src/lora_validate.py", line 240, in validate_main
#     raise ValueError(
#     ...<2 lines>...
#     )
# ValueError: No experiment found in EXPERIMENTS.jsonl for DoRA+/qwen2.5-0.5b_C_1k (version=v2.0). Pass --timestamp explicitly or use --local.
#   FAILED in 10s
#
#   Testing qwen2.5-0.5b_D_1k...
#
# ============================================================
#   DoRA+ Evaluation — qwen2.5-0.5b_D_1k
#   Split    : test  (100 examples)
#   Source   : kon172verma/intent-classifier-experiments/v2.0/qwen2.5-0.5b_DoRA+_D_1k_20260826-044049
#   Device   : cuda
# ============================================================
#
#   Loading base model: Qwen/Qwen2.5-0.5B-Instruct
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
#
# Loading weights:   0%|          | 0/290 [00:00<?, ?it/s]
# Loading weights:  26%|██▌       | 76/290 [00:00<00:00, 744.92it/s]
# Loading weights:  71%|███████▏  | 207/290 [00:00<00:00, 1066.96it/s]
# Loading weights: 100%|██████████| 290/290 [00:00<00:00, 1092.34it/s]
#   Loading adapter from HF: kon172verma/intent-classifier-experiments/v2.0/qwen2.5-0.5b_DoRA+_D_1k_20260826-044049
#   [  20/100]  running_acc=0.800
#   [  40/100]  running_acc=0.850
#   [  60/100]  running_acc=0.850
#   [  80/100]  running_acc=0.838
#   [ 100/100]  running_acc=0.860
#   Report pushed  : kon172verma/intent-classifier-experiments/reports/v2.0/doraplus/reports_test/qwen2.5-0.5b_D_1k_test_20260826_100719.json
#
#   Accuracy   : 0.8600  (86/100)
#   Avg latency: 255.6 ms
#   Peak memory: 1166 MB
#   Report     : /content/intent-classifier/finetune_DoRAplus/reports_test/qwen2.5-0.5b_D_1k_test_20260826_100719.json
#   OK in 43s
#
#   Testing qwen3-0.6b_A_1k...
#
# ============================================================
#   DoRA+ Evaluation — qwen3-0.6b_A_1k
#   Split    : test  (100 examples)
#   Source   : kon172verma/intent-classifier-experiments/v2.0/qwen3-0.6b_DoRA+_A_1k_20260826-045211
#   Device   : cuda
# ============================================================
#
#   Loading base model: Qwen/Qwen3-0.6B
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
#
# Loading weights:   0%|          | 0/311 [00:00<?, ?it/s]
# Loading weights:   1%|          | 2/311 [00:00<00:22, 14.04it/s]
# Loading weights:  43%|████▎     | 134/311 [00:00<00:00, 666.86it/s]
# Loading weights:  83%|████████▎ | 259/311 [00:00<00:00, 904.42it/s]
# Loading weights: 100%|██████████| 311/311 [00:00<00:00, 809.27it/s]
#   Loading adapter from HF: kon172verma/intent-classifier-experiments/v2.0/qwen3-0.6b_DoRA+_A_1k_20260826-045211
#   [  20/100]  running_acc=1.000
#   [  40/100]  running_acc=1.000
#   [  60/100]  running_acc=1.000
#   [  80/100]  running_acc=1.000
#   [ 100/100]  running_acc=0.990
#   Report pushed  : kon172verma/intent-classifier-experiments/reports/v2.0/doraplus/reports_test/qwen3-0.6b_A_1k_test_20260826_100753.json
#
#   Accuracy   : 0.9900  (99/100)
#   Avg latency: 154.5 ms
#   Peak memory: 1290 MB
#   Report     : /content/intent-classifier/finetune_DoRAplus/reports_test/qwen3-0.6b_A_1k_test_20260826_100753.json
#   OK in 32s
#
#   Testing qwen3-0.6b_B_1k...
#
# ============================================================
#   DoRA+ Evaluation — qwen3-0.6b_B_1k
#   Split    : test  (100 examples)
#   Source   : kon172verma/intent-classifier-experiments/v2.0/qwen3-0.6b_DoRA+_B_1k_20260826-050540
#   Device   : cuda
# ============================================================
#
#   Loading base model: Qwen/Qwen3-0.6B
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
#
# Loading weights:   0%|          | 0/311 [00:00<?, ?it/s]
# Loading weights:   0%|          | 1/311 [00:00<00:47,  6.58it/s]
# Loading weights:  43%|████▎     | 135/311 [00:00<00:00, 652.82it/s]
# Loading weights:  83%|████████▎ | 259/311 [00:00<00:00, 892.70it/s]
# Loading weights: 100%|██████████| 311/311 [00:00<00:00, 794.45it/s]
#   Loading adapter from HF: kon172verma/intent-classifier-experiments/v2.0/qwen3-0.6b_DoRA+_B_1k_20260826-050540
#   [  20/100]  running_acc=1.000
#   [  40/100]  running_acc=1.000
#   [  60/100]  running_acc=0.983
#   [  80/100]  running_acc=0.988
#   [ 100/100]  running_acc=0.990
#   Report pushed  : kon172verma/intent-classifier-experiments/reports/v2.0/doraplus/reports_test/qwen3-0.6b_B_1k_test_20260826_100831.json
#
#   Accuracy   : 0.9900  (99/100)
#   Avg latency: 213.3 ms
#   Peak memory: 1305 MB
#   Report     : /content/intent-classifier/finetune_DoRAplus/reports_test/qwen3-0.6b_B_1k_test_20260826_100831.json
#   OK in 39s
#
#   Testing qwen3-0.6b_C_1k...
# Traceback (most recent call last):
#   File "/content/intent-classifier/finetune_DoRAplus/src/doraplus_validate.py", line 28, in <module>
#     run_validate_wrapper(
#     ~~~~~~~~~~~~~~~~~~~~^
#         __file__,
#         ^^^^^^^^^
#         technique="DoRA+",
#         ^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/content/intent-classifier/finetune_lib/wrappers.py", line 95, in run_validate_wrapper
#     lora_validate.validate_main(**kwargs)
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^
#   File "/content/intent-classifier/finetune_LoRA/src/lora_validate.py", line 240, in validate_main
#     raise ValueError(
#     ...<2 lines>...
#     )
# ValueError: No experiment found in EXPERIMENTS.jsonl for DoRA+/qwen3-0.6b_C_1k (version=v2.0). Pass --timestamp explicitly or use --local.
#   FAILED in 10s
#
#   Testing qwen3-0.6b_D_1k...
#
# ============================================================
#   DoRA+ Evaluation — qwen3-0.6b_D_1k
#   Split    : test  (100 examples)
#   Source   : kon172verma/intent-classifier-experiments/v2.0/qwen3-0.6b_DoRA+_D_1k_20260826-052401
#   Device   : cuda
# ============================================================
#
#   Loading base model: Qwen/Qwen3-0.6B
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
#
# Loading weights:   0%|          | 0/311 [00:00<?, ?it/s]
# Loading weights:   0%|          | 1/311 [00:00<00:38,  7.96it/s]
# Loading weights:  41%|████      | 127/311 [00:00<00:00, 673.58it/s]
# Loading weights:  80%|███████▉  | 248/311 [00:00<00:00, 903.27it/s]
# Loading weights: 100%|██████████| 311/311 [00:00<00:00, 828.33it/s]
#   Loading adapter from HF: kon172verma/intent-classifier-experiments/v2.0/qwen3-0.6b_DoRA+_D_1k_20260826-052401
#   [  20/100]  running_acc=1.000
#   [  40/100]  running_acc=1.000
#   [  60/100]  running_acc=1.000
#   [  80/100]  running_acc=1.000
#   [ 100/100]  running_acc=1.000
#   Report pushed  : kon172verma/intent-classifier-experiments/reports/v2.0/doraplus/reports_test/qwen3-0.6b_D_1k_test_20260826_100929.json
#
#   Accuracy   : 1.0000  (100/100)
#   Avg latency: 299.3 ms
#   Peak memory: 1395 MB
#   Report     : /content/intent-classifier/finetune_DoRAplus/reports_test/qwen3-0.6b_D_1k_test_20260826_100929.json
#   OK in 48s
#
#   Testing llama3.2-1b_A_1k...
#
# ============================================================
#   DoRA+ Evaluation — llama3.2-1b_A_1k
#   Split    : test  (100 examples)
#   Source   : kon172verma/intent-classifier-experiments/v2.0/llama3.2-1b_DoRA+_A_1k_20260826-053607
#   Device   : cuda
# ============================================================
#
#   Loading base model: meta-llama/Llama-3.2-1B-Instruct
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
#
# Loading weights:   0%|          | 0/146 [00:00<?, ?it/s]
# Loading weights:   1%|          | 1/146 [00:00<00:19,  7.47it/s]
# Loading weights:  21%|██        | 31/146 [00:00<00:00, 157.31it/s]
# Loading weights:  40%|████      | 59/146 [00:00<00:00, 208.15it/s]
# Loading weights:  64%|██████▎   | 93/146 [00:00<00:00, 250.85it/s]
# Loading weights:  83%|████████▎ | 121/146 [00:00<00:00, 259.57it/s]
# Loading weights: 100%|██████████| 146/146 [00:00<00:00, 235.13it/s]
#   Loading adapter from HF: kon172verma/intent-classifier-experiments/v2.0/llama3.2-1b_DoRA+_A_1k_20260826-053607
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer TokenizersBackend. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
#   [  20/100]  running_acc=0.900
#   [  40/100]  running_acc=0.950
#   [  60/100]  running_acc=0.967
#   [  80/100]  running_acc=0.975
#   [ 100/100]  running_acc=0.970
#   Report pushed  : kon172verma/intent-classifier-experiments/reports/v2.0/doraplus/reports_test/llama3.2-1b_A_1k_test_20260826_100956.json
#
#   Accuracy   : 0.9700  (97/100)
#   Avg latency: 84.7 ms
#   Peak memory: 2478 MB
#   Report     : /content/intent-classifier/finetune_DoRAplus/reports_test/llama3.2-1b_A_1k_test_20260826_100956.json
#   OK in 27s
#
#   Testing llama3.2-1b_B_1k...
#
# ============================================================
#   DoRA+ Evaluation — llama3.2-1b_B_1k
#   Split    : test  (100 examples)
#   Source   : kon172verma/intent-classifier-experiments/v2.0/llama3.2-1b_DoRA+_B_1k_20260826-055029
#   Device   : cuda
# ============================================================
#
#   Loading base model: meta-llama/Llama-3.2-1B-Instruct
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
#
# Loading weights:   0%|          | 0/146 [00:00<?, ?it/s]
# Loading weights:   1%|          | 1/146 [00:00<00:18,  7.91it/s]
# Loading weights:  21%|██        | 30/146 [00:00<00:00, 155.73it/s]
# Loading weights:  40%|███▉      | 58/146 [00:00<00:00, 207.36it/s]
# Loading weights:  59%|█████▉    | 86/146 [00:00<00:00, 232.92it/s]
# Loading weights:  82%|████████▏ | 120/146 [00:00<00:00, 263.45it/s]
# Loading weights: 100%|██████████| 146/146 [00:00<00:00, 233.69it/s]
#   Loading adapter from HF: kon172verma/intent-classifier-experiments/v2.0/llama3.2-1b_DoRA+_B_1k_20260826-055029
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer TokenizersBackend. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
#   [  20/100]  running_acc=0.950
#   [  40/100]  running_acc=0.975
#   [  60/100]  running_acc=0.950
#   [  80/100]  running_acc=0.963
#   [ 100/100]  running_acc=0.970
#   Report pushed  : kon172verma/intent-classifier-experiments/reports/v2.0/doraplus/reports_test/llama3.2-1b_B_1k_test_20260826_101026.json
#
#   Accuracy   : 0.9700  (97/100)
#   Avg latency: 121.2 ms
#   Peak memory: 2496 MB
#   Report     : /content/intent-classifier/finetune_DoRAplus/reports_test/llama3.2-1b_B_1k_test_20260826_101026.json
#   OK in 30s
#
#   Testing llama3.2-1b_C_1k...
#
# ============================================================
#   DoRA+ Evaluation — llama3.2-1b_C_1k
#   Split    : test  (100 examples)
#   Source   : kon172verma/intent-classifier-experiments/v2.0/llama3.2-1b_DoRA+_C_1k_20260826-062643
#   Device   : cuda
# ============================================================
#
#   Loading base model: meta-llama/Llama-3.2-1B-Instruct
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
#
# Loading weights:   0%|          | 0/146 [00:00<?, ?it/s]
# Loading weights:   1%|          | 1/146 [00:00<00:21,  6.70it/s]
# Loading weights:  22%|██▏       | 32/146 [00:00<00:00, 153.07it/s]
# Loading weights:  43%|████▎     | 63/146 [00:00<00:00, 217.13it/s]
# Loading weights:  64%|██████▎   | 93/146 [00:00<00:00, 243.30it/s]
# Loading weights:  83%|████████▎ | 121/146 [00:00<00:00, 251.77it/s]
# Loading weights: 100%|██████████| 146/146 [00:00<00:00, 228.60it/s]
#   Loading adapter from HF: kon172verma/intent-classifier-experiments/v2.0/llama3.2-1b_DoRA+_C_1k_20260826-062643
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer TokenizersBackend. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
#   [  20/100]  running_acc=1.000
#   [  40/100]  running_acc=1.000
#   [  60/100]  running_acc=1.000
#   [  80/100]  running_acc=1.000
#   [ 100/100]  running_acc=1.000
#   Report pushed  : kon172verma/intent-classifier-experiments/reports/v2.0/doraplus/reports_test/llama3.2-1b_C_1k_test_20260826_101129.json
#
#   Accuracy   : 1.0000  (100/100)
#   Avg latency: 447.3 ms
#   Peak memory: 2813 MB
#   Report     : /content/intent-classifier/finetune_DoRAplus/reports_test/llama3.2-1b_C_1k_test_20260826_101129.json
#   OK in 63s
#
#   Testing llama3.2-1b_D_1k...
#
# ============================================================
#   DoRA+ Evaluation — llama3.2-1b_D_1k
#   Split    : test  (100 examples)
#   Source   : kon172verma/intent-classifier-experiments/v2.0/llama3.2-1b_DoRA+_D_1k_20260826-070251
#   Device   : cuda
# ============================================================
#
#   Loading base model: meta-llama/Llama-3.2-1B-Instruct
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
#
# Loading weights:   0%|          | 0/146 [00:00<?, ?it/s]
# Loading weights:   1%|          | 1/146 [00:00<00:17,  8.49it/s]
# Loading weights:  21%|██        | 30/146 [00:00<00:00, 159.40it/s]
# Loading weights:  40%|███▉      | 58/146 [00:00<00:00, 209.28it/s]
# Loading weights:  59%|█████▉    | 86/146 [00:00<00:00, 234.14it/s]
# Loading weights:  82%|████████▏ | 120/146 [00:00<00:00, 264.39it/s]
# Loading weights: 100%|██████████| 146/146 [00:00<00:00, 235.96it/s]
#   Loading adapter from HF: kon172verma/intent-classifier-experiments/v2.0/llama3.2-1b_DoRA+_D_1k_20260826-070251
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer TokenizersBackend. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
#   [  20/100]  running_acc=1.000
#   [  40/100]  running_acc=1.000
#   [  60/100]  running_acc=1.000
#   [  80/100]  running_acc=0.988
#   [ 100/100]  running_acc=0.990
#   Report pushed  : kon172verma/intent-classifier-experiments/reports/v2.0/doraplus/reports_test/llama3.2-1b_D_1k_test_20260826_101233.json
#
#   Accuracy   : 0.9900  (99/100)
#   Avg latency: 452.0 ms
#   Peak memory: 2857 MB
#   Report     : /content/intent-classifier/finetune_DoRAplus/reports_test/llama3.2-1b_D_1k_test_20260826_101233.json
#   OK in 64s
#
#   Testing smollm2-1.7b_A_1k...
#
# ============================================================
#   DoRA+ Evaluation — smollm2-1.7b_A_1k
#   Split    : test  (100 examples)
#   Source   : kon172verma/intent-classifier-experiments/v2.0/smollm2-1.7b_DoRA+_A_1k_20260826-072348
#   Device   : cuda
# ============================================================
#
#   Loading base model: HuggingFaceTB/SmolLM2-1.7B-Instruct
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
#
# Loading weights:   0%|          | 0/218 [00:00<?, ?it/s]
# Loading weights:  10%|▉         | 21/218 [00:00<00:00, 203.16it/s]
# Loading weights:  22%|██▏       | 48/218 [00:00<00:00, 240.10it/s]
# Loading weights:  34%|███▍      | 75/218 [00:00<00:00, 251.54it/s]
# Loading weights:  47%|████▋     | 102/218 [00:00<00:00, 256.22it/s]
# Loading weights:  59%|█████▉    | 129/218 [00:00<00:00, 258.81it/s]
# Loading weights:  72%|███████▏  | 156/218 [00:00<00:00, 261.22it/s]
# Loading weights:  84%|████████▍ | 183/218 [00:00<00:00, 261.50it/s]
# Loading weights:  96%|█████████▋| 210/218 [00:00<00:00, 262.07it/s]
# Loading weights: 100%|██████████| 218/218 [00:00<00:00, 258.19it/s]
#   Loading adapter from HF: kon172verma/intent-classifier-experiments/v2.0/smollm2-1.7b_DoRA+_A_1k_20260826-072348
#   [  20/100]  running_acc=0.950
#   [  40/100]  running_acc=0.975
#   [  60/100]  running_acc=0.983
#   [  80/100]  running_acc=0.988
#   [ 100/100]  running_acc=0.980
#   Report pushed  : kon172verma/intent-classifier-experiments/reports/v2.0/doraplus/reports_test/smollm2-1.7b_A_1k_test_20260826_101303.json
#
#   Accuracy   : 0.9800  (98/100)
#   Avg latency: 126.4 ms
#   Peak memory: 3540 MB
#   Report     : /content/intent-classifier/finetune_DoRAplus/reports_test/smollm2-1.7b_A_1k_test_20260826_101303.json
#   OK in 29s
#
#   Testing smollm2-1.7b_B_1k...
#
# ============================================================
#   DoRA+ Evaluation — smollm2-1.7b_B_1k
#   Split    : test  (100 examples)
#   Source   : kon172verma/intent-classifier-experiments/v2.0/smollm2-1.7b_DoRA+_B_1k_20260826-074958
#   Device   : cuda
# ============================================================
#
#   Loading base model: HuggingFaceTB/SmolLM2-1.7B-Instruct
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
#
# Loading weights:   0%|          | 0/218 [00:00<?, ?it/s]
# Loading weights:   6%|▋         | 14/218 [00:00<00:01, 134.71it/s]
# Loading weights:  19%|█▉        | 41/218 [00:00<00:00, 209.66it/s]
# Loading weights:  31%|███       | 68/218 [00:00<00:00, 233.59it/s]
# Loading weights:  44%|████▎     | 95/218 [00:00<00:00, 243.34it/s]
# Loading weights:  56%|█████▌    | 122/218 [00:00<00:00, 249.56it/s]
# Loading weights:  68%|██████▊   | 149/218 [00:00<00:00, 254.29it/s]
# Loading weights:  81%|████████  | 176/218 [00:00<00:00, 256.78it/s]
# Loading weights:  93%|█████████▎| 203/218 [00:00<00:00, 258.78it/s]
# Loading weights: 100%|██████████| 218/218 [00:00<00:00, 250.85it/s]
#   Loading adapter from HF: kon172verma/intent-classifier-experiments/v2.0/smollm2-1.7b_DoRA+_B_1k_20260826-074958
#   [  20/100]  running_acc=1.000
#   [  40/100]  running_acc=1.000
#   [  60/100]  running_acc=0.983
#   [  80/100]  running_acc=0.975
#   [ 100/100]  running_acc=0.970
#   Report pushed  : kon172verma/intent-classifier-experiments/reports/v2.0/doraplus/reports_test/smollm2-1.7b_B_1k_test_20260826_101338.json
#
#   Accuracy   : 0.9700  (97/100)
#   Avg latency: 184.3 ms
#   Peak memory: 3565 MB
#   Report     : /content/intent-classifier/finetune_DoRAplus/reports_test/smollm2-1.7b_B_1k_test_20260826_101338.json
#   OK in 35s
#
#   Testing smollm2-1.7b_C_1k...
#
# ============================================================
#   DoRA+ Evaluation — smollm2-1.7b_C_1k
#   Split    : test  (100 examples)
#   Source   : kon172verma/intent-classifier-experiments/v2.0/smollm2-1.7b_DoRA+_C_1k_20260826-084923
#   Device   : cuda
# ============================================================
#
#   Loading base model: HuggingFaceTB/SmolLM2-1.7B-Instruct
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
#
# Loading weights:   0%|          | 0/218 [00:00<?, ?it/s]
# Loading weights:   8%|▊         | 17/218 [00:00<00:01, 169.88it/s]
# Loading weights:  20%|█▉        | 43/218 [00:00<00:00, 222.50it/s]
# Loading weights:  31%|███       | 68/218 [00:00<00:00, 234.87it/s]
# Loading weights:  44%|████▎     | 95/218 [00:00<00:00, 245.41it/s]
# Loading weights:  56%|█████▌    | 122/218 [00:00<00:00, 251.51it/s]
# Loading weights:  68%|██████▊   | 149/218 [00:00<00:00, 255.60it/s]
# Loading weights:  81%|████████  | 176/218 [00:00<00:00, 257.17it/s]
# Loading weights:  93%|█████████▎| 203/218 [00:00<00:00, 258.89it/s]
# Loading weights: 100%|██████████| 218/218 [00:00<00:00, 253.81it/s]
#   Loading adapter from HF: kon172verma/intent-classifier-experiments/v2.0/smollm2-1.7b_DoRA+_C_1k_20260826-084923
#   [  20/100]  running_acc=1.000
#   [  40/100]  running_acc=1.000
#   [  60/100]  running_acc=1.000
#   [  80/100]  running_acc=1.000
#   [ 100/100]  running_acc=0.990
#   Report pushed  : kon172verma/intent-classifier-experiments/reports/v2.0/doraplus/reports_test/smollm2-1.7b_C_1k_test_20260826_101505.json
#
#   Accuracy   : 0.9900  (99/100)
#   Avg latency: 702.8 ms
#   Peak memory: 3901 MB
#   Report     : /content/intent-classifier/finetune_DoRAplus/reports_test/smollm2-1.7b_C_1k_test_20260826_101505.json
#   OK in 87s
#
#   Testing smollm2-1.7b_D_1k...
#
# ============================================================
#   DoRA+ Evaluation — smollm2-1.7b_D_1k
#   Split    : test  (100 examples)
#   Source   : kon172verma/intent-classifier-experiments/v2.0/smollm2-1.7b_DoRA+_D_1k_20260826-094624
#   Device   : cuda
# ============================================================
#
#   Loading base model: HuggingFaceTB/SmolLM2-1.7B-Instruct
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
#
# Loading weights:   0%|          | 0/218 [00:00<?, ?it/s]
# Loading weights:   6%|▋         | 14/218 [00:00<00:01, 137.77it/s]
# Loading weights:  19%|█▉        | 41/218 [00:00<00:00, 210.92it/s]
# Loading weights:  31%|███       | 68/218 [00:00<00:00, 232.45it/s]
# Loading weights:  44%|████▎     | 95/218 [00:00<00:00, 241.01it/s]
# Loading weights:  56%|█████▌    | 122/218 [00:00<00:00, 246.49it/s]
# Loading weights:  68%|██████▊   | 149/218 [00:00<00:00, 250.54it/s]
# Loading weights:  81%|████████  | 176/218 [00:00<00:00, 254.21it/s]
# Loading weights:  93%|█████████▎| 203/218 [00:00<00:00, 255.49it/s]
# Loading weights: 100%|██████████| 218/218 [00:00<00:00, 248.52it/s]
#   Loading adapter from HF: kon172verma/intent-classifier-experiments/v2.0/smollm2-1.7b_DoRA+_D_1k_20260826-094624
#   [  20/100]  running_acc=1.000
#   [  40/100]  running_acc=1.000
#   [  60/100]  running_acc=1.000
#   [  80/100]  running_acc=0.988
#   [ 100/100]  running_acc=0.990
#   Report pushed  : kon172verma/intent-classifier-experiments/reports/v2.0/doraplus/reports_test/smollm2-1.7b_D_1k_test_20260826_101634.json
#
#   Accuracy   : 0.9900  (99/100)
#   Avg latency: 710.5 ms
#   Peak memory: 3971 MB
#   Report     : /content/intent-classifier/finetune_DoRAplus/reports_test/smollm2-1.7b_D_1k_test_20260826_101634.json
#   OK in 88s

# %% [markdown]
# ## 11. Inference sanity check
#
# Manually inspect model outputs on a few hand-picked examples.
# This catches output format issues that aggregate accuracy metrics would not surface.

# %%
import json
import sys
import torch
from pathlib import Path

# Pick any run_tag to inspect
INSPECT_MODEL  = MODELS_TO_RUN[0]
INSPECT_CONFIG = CONFIGS_TO_RUN[0]

if REPO_DIR not in sys.path:
    sys.path.insert(0, REPO_DIR)

from finetune_lib import (
    CURRENT_VERSION, FINETUNE_MODEL_REGISTRY, HF_EXPERIMENTS_REPO,
    answer_to_tool_id, apply_chat_template_safe, build_chat_messages,
    extract_prediction, load_jsonl, tool_id_to_answer,
)
from finetune_lib.registry import find_latest_experiment
from transformers import AutoModelForCausalLM, AutoTokenizer
from peft import PeftModel

model_id = FINETUNE_MODEL_REGISTRY[INSPECT_MODEL]
run_tag  = f"{INSPECT_MODEL}_{INSPECT_CONFIG}_{DATASET_SIZE}"
local_adapter = Path(REPO_DIR) / "finetune_DoRAplus" / "adapters" / run_tag

entry = find_latest_experiment(
    technique="DoRA+",
    model_key=INSPECT_MODEL,
    lora_config=INSPECT_CONFIG,
    dataset_size=DATASET_SIZE,
    version=CURRENT_VERSION,
)
hf_sub = entry["hf_subfolder"] if entry else None
if not local_adapter.exists() and not hf_sub:
    raise RuntimeError(
        f"No adapter found for {run_tag}. Smoke tests do not save/push "
        "adapters; run full training first, or set INSPECT_MODEL / "
        "INSPECT_CONFIG to a completed run."
    )

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
dtype  = torch.bfloat16 if device.type == "cuda" else torch.float32

tokenizer  = AutoTokenizer.from_pretrained(model_id)
base_model = AutoModelForCausalLM.from_pretrained(model_id, torch_dtype=dtype, device_map={"": device})
if local_adapter.exists():
    print(f"Loading local adapter: {local_adapter}")
    model = PeftModel.from_pretrained(base_model, str(local_adapter))
elif hf_sub:
    print(f"Loading HF adapter: {HF_EXPERIMENTS_REPO}/{hf_sub}")
    model = PeftModel.from_pretrained(base_model, HF_EXPERIMENTS_REPO, subfolder=hf_sub)
model.eval()

val_file = Path(f"{DATA_DIR}/{DATASET_SIZE}/val.jsonl")
examples = load_jsonl(val_file)[:5]  # first 5 examples

for i, ex in enumerate(examples, 1):
    msgs = build_chat_messages(ex, include_answer=False)
    text = apply_chat_template_safe(tokenizer, msgs, INSPECT_MODEL, add_generation_prompt=True)
    inp  = tokenizer(text, return_tensors="pt").to(device)
    with torch.no_grad():
        out = model.generate(**inp, max_new_tokens=8, do_sample=False,
                             pad_token_id=int(tokenizer.eos_token_id))
    new_ids = out[0][inp["input_ids"].shape[1]:]
    raw     = tokenizer.decode(new_ids, skip_special_tokens=True)
    pred    = extract_prediction(raw)
    answer_id = answer_to_tool_id(ex)
    pred_tool = tool_id_to_answer(ex, pred)
    correct = pred == answer_id
    print(f"[{i}] user_request={ex['user_request'][:60]!r}")
    print(f"     expected={answer_id!r} ({ex['answer']})  got={pred!r} ({pred_tool})  raw={raw!r}  {'✓' if correct else '✗'}")
    print()
# Out:
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights:   0%|          | 0/290 [00:00<?, ?it/s]
# Loading local adapter: /content/intent-classifier/finetune_DoRAplus/adapters/smollm2-360m_A_1k
# [1] user_request="I'm locked out of my car, can someone come help?"
#      expected='n' (roadside_assistance)  got='o' (safety_proposal)  raw='o'  ✗
#
# [2] user_request='Do I have a contact called Sarah in my list?'
#      expected='c' (corp-contact-sync)  got='c' (corp-contact-sync)  raw='c'  ✓
#
# [3] user_request='What is the population of Japan?'
#      expected='-' (none)  got='-' (none)  raw='-'  ✓
#
# [4] user_request='Schedule a meeting with Tanaka-san at 3 pm tomorrow.'
#      expected='o' (corp-scheduler-app)  got='o' (corp-scheduler-app)  raw='o'  ✓
#
# [5] user_request="Send a text to mom saying I'll be late."
#      expected='d' (sms_messenger)  got='d' (sms_messenger)  raw='d'  ✓

# %% [markdown]
# ## 12. Download reports
#
# Zips and downloads all JSON report files so you can run plot scripts locally.
#
# Contents of the zip:
# - `reports_training/` — training curves + log history (one JSON per run)
# - `reports_validation/` — validation accuracy (one JSON per run)
# - `reports_test/` — test accuracy + per-tool metrics (one JSON per run)

# %%
import os
import shutil
from pathlib import Path

try:
    from google.colab import files  # type: ignore

    doraplus_dir = Path(REPO_DIR) / "finetune_DoRAplus"
    zip_base = "/content/doraplus_reports"

    report_dirs = {
        "reports_training":   doraplus_dir / "reports_training",
        "reports_validation": doraplus_dir / "reports_validation",
        "reports_test":       doraplus_dir / "reports_test",
    }

    staging = Path("/content/_doraplus_reports_staging")
    staging.mkdir(exist_ok=True)
    for name, src in report_dirs.items():
        if src.exists() and any(src.iterdir()):
            shutil.copytree(src, staging / name, dirs_exist_ok=True)
        else:
            print(f"  Skipping {name} (empty or missing)")

    shutil.make_archive(zip_base, "zip", staging)
    print(f"Created {zip_base}.zip")
    files.download(f"{zip_base}.zip")

except ImportError:
    print("Not running in Colab — copy reports manually from:")
    for name in ["reports_training", "reports_validation", "reports_test"]:
        print(f"  {REPO_DIR}/finetune_DoRAplus/{name}/")
# Out:
# Created /content/doraplus_reports.zip
